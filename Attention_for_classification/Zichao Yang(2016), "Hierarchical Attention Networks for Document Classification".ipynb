# %% [markdown]
# 해당 페이지는 Zichao Yang1, Diyi Yang1, Chris Dyer1, Xiaodong He2, Alex Smola1, Eduard Hovy1 (2016), "Hierarchical Attention Networks for Document Classification" 논문에 관한 구현입니다.
# http://www.cs.cmu.edu/~./hovy/papers/16HLT-hierarchical-attention-networks.pdf
#
# __________________________________
#
# references :
# - https://github.com/pandeykartikey/Hierarchical-Attention-Network/blob/master/HAN%20yelp.ipynb
# - https://github.com/vietnguyen91/Hierarchical-attention-networks-pytorch/blob/master/src/utils.py
# - https://github.com/EdGENetworks/attention-networks-for-classification/blob/master/attention_model_validation_experiments.ipynb

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import torch.nn.functional as F
from torch.utils import data

from nltk.tokenize import sent_tokenize,word_tokenize
from sklearn.model_selection import train_test_split

import string
import random
import re
import pandas as pd
from bs4 import BeautifulSoup
import os
from collections import defaultdict,Counter
import pickle

from termcolor import colored, cprint
SEED = 1

random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# # Loading

# %%
os.chmod("yelp_academic_dataset_review.json", 0o777)

# %%
df_iter = pd.read_json('yelp_academic_dataset_review.json',lines=True,chunksize=100000)

# %%
df = pd.concat(df_iter,axis=0)
df.shape
# Out:
# (6685900, 9)

# %%
df = df.head(1000000)
df.shape
# 데이터가 너무 많아서 100만개만 사용합니다.
# Out:
# (1000000, 9)

# %% [markdown]
# # Preprocessing

# %%
def clean_str(string, max_seq_len):
    """
    adapted from https://github.com/yoonkim/CNN_sentence/blob/master/process_data.py
    """
    string = BeautifulSoup(string, "lxml").text
    string = re.sub(r"[^A-Za-z0-9(),!?\"\`]", " ", string)
    string = re.sub(r"\"s", " \"s", string)
    string = re.sub(r"\"ve", " \"ve", string)
    string = re.sub(r"n\"t", " n\"t", string)
    string = re.sub(r"\"re", " \"re", string)
    string = re.sub(r"\"d", " \"d", string)
    string = re.sub(r"\"ll", " \"ll", string)
    string = re.sub(r",", " , ", string)
    string = re.sub(r"!", " ! ", string)
    string = re.sub(r"\(", " \( ", string)
    string = re.sub(r"\)", " \) ", string)
    string = re.sub(r"\?", " \? ", string)
    string = re.sub(r"\s{2,}", " ", string)
    s =string.strip().lower().split(" ")
    if len(s) > max_seq_len:
        return s[0:max_seq_len] 
    return s

# %%
X = df['text']
Y = (df['stars'] - 1)
X_train, X_test, y_train, y_test = \
train_test_split(X,Y, test_size=0.33, random_state=123)

# %%
X_train.head()
# Out:
# 501213    Quite disturbed by no team work, seems to be s...
# 805861    Based on flavour of the food and quality of th...
# 882726    My sister was visiting and we were looking for...
# 371658    Some of the best food in the area. Great selec...
# 409957    the food is always great!, lots of vegetarian ...
# Name: text, dtype: object

# %%
def create3DList(data, max_sent_len,max_seq_len):
    x = []; x1 = []
    for seq in sent_tokenize(data) :
        x1.append(clean_str(seq,max_sent_len))
    x.append(x1[:max_seq_len])
    return x

# max_sent_len : 한 문장에 들어가는 단어의 갯수
# max_seq_len : 한 문서에 들어가는 문장의 갯수
max_sent_len = 12; max_seq_len = 25

x_train = X_train.apply(lambda x : create3DList(x,max_sent_len,max_seq_len))
x_test = X_test.apply(lambda x : create3DList(x,max_sent_len,max_seq_len))

print("x_train: {}".format(len(x_train)))
print("x_test: {}".format(len(x_test)))
# Out:
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:272: UserWarning: "b'.'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.yelp.com/biz_photos/-Dnh48f029YNugtMKkkI-Q?select=dUlITiNdAY5kue075cevJQ#dUlITiNdAY5kue075cevJQ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://marcos.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.youtube.com/watch?v=Lxj4SIVqL24&feature=related" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.rvlostyet.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://m.facebook.com/michael.c.hardy.9/activity/1697247313671953" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://vegas.eater.com/maps/46-places-to-eat-brunch-in-las-vegas-dec-2014" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.consumeraffairs.com/news/mypillow-gets-a-rude-awakening-as-the-better-business-bureau-gives-it-an-f-010517.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:272: UserWarning: "b'..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.youtube.com/watch?v=ZsABTmT1_M0" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.azcentral.com/news/articles/2008/05/18/20080518priceofdeath0511.html#comments" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://youtu.be/_I8Si12nEMs" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://facebook.com/splitbreed" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://doctorautolv.com/promotions/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.ncdoj.gov/Consumer/Health/Health-Clubs-and-Gyms.aspx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.ada.gov/archive/qasrvc.htmhttps://www.ada.gov/archive/qasrvc.htm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://myfloridalegal.com/webfiles.nsf/WF/KMAN-A83T35/$file/Youfitavc.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.consumeraffairs.com/news04/2005/az_o_premium.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://lagamio.com/2014/04/25/pinball-hall-of-fame/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.yelp.com/biz_photos/nsEO3MRzYLKfgtID7gvArw?select=h_wy_MqnFW0L397uYsQOig
# http://www.yelp.com/biz_photos/nsEO3MRzYLKfgtID7gvArw?select=1UOxVH3vvYGkwv7HZ_H8Cw
# http://www.yelp.com/biz_photos/nsEO3MRzYLKfgtID7gvArw?select=ryVQVqRPyJylpYzi-XZezQ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.giovannicarrelli.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.bbb.org/central-northern-western-arizona/business-reviews/movers/thompson-moving-llc-in-glendale-az-97008296/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.youtube.com/watch?v=X1XilfKuYaQ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://tinyurl.com/22lmfqu" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://veganhostess.com/vegan-cleveland-restaurants-coffee-shops-more/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.facebook.com...." looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.koreanharvestfest.com/en/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.yelp.com/biz_photos/nsEO3MRzYLKfgtID7gvArw?select=9vEQ2jKcRGjryTyVEvZDmA
# http://www.yelp.com/biz_photos/nsEO3MRzYLKfgtID7gvArw?select=w1hAI5b7FWBJ1WNQzRpplg" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://youtu.be/TzZG2h7WJNU" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.amcllc.net/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.aurabasiliquemontreal.com/en/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.cbc.ca/news/canada/montreal/story/2013/09/12/quebec-waitress-fired-drunk-customer-driver.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.mcninchhouserestaurant.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://mitchells.tv/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://odessapoissonnier.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.ad-international.org/animals_in_entertainment/go.php?id=4020&ssi=11" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.virginamerica.com/travel/cabins.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.marleneharriscol.com/antique-style-wedding-bands/diamonds-floral-milgrain-WBFLO-3" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.gayot.com/best-restaurants/2010/top10-newrestaurants.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.circuitcity.com." looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.fossilandhaggis.com/everyday-specials.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://il.healthinspections.us/champaign/estab.cfm?facilityID=2319" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://m.youtube.com/watch?v=afppDmrK0Ac" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.kevinlepine.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://ziarecords.com/Home" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.facebook.com/coxcommunications?fref=ts" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.azmd.gov/DoctorSearch/DoctorSearch/doctor-search" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.appalachianoutfitters.com/products-page/fly-fishing/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://blogs.windsorstar.com/2013/07/10/windsor-man-blocked-from-legoland/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.attorneysteve.net" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.girlabouttoronto.com/?s=glas" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.tripadvisor.com/ShowUserReviews-g45963-d491198-r275849108-All_American_Bar_Grille-Las_Vegas_Nevada.html#" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://eatnorthandsouth.com/smokehouse-info/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.bordergrill.com/PDF/BGLV_Brunch_Flyer_0310_Flyer.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.tripadvisor.ca/ShowUserReviews-g181740-d3210273-r334838965-Jim_Chai_Kee_Noodle-Richmond_Hill_Ontario.html#" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.yelp.com/biz_photos/AbadN65irz8uSL8z6fkoBg?select=ifwxHWilWKPkBEmMxGi_6A" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.twitter.com/ceciliauc" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.facebook.com/media/set/?set=a.10150479969916969.365313.628961968&type=3
#
# O=;-D" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.maricopa.gov/Pets/AboutUs/Default.aspx
# http://azfaccs.org.mywebsitebuild.com/about/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.bbb.org/central-florida/business-reviews/auto-renting-and-leasing/e-z-rent-a-car-in-orlando-fl-17000134/reviews-and-complaints" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://il.healthinspections.us/champaign/estab.cfm?facilityID=2499" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.probikesllc.com/index.php" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.theabsoluteorganics.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.tripadvisor.com/ShowUserReviews-g45963-d492192-r318977057-Cravings_Buffet_at_The_Mirage-Las_Vegas_Nevada.html#" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.iihs.org/ratings." looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.post-gazette.com/pg/09145/972563-46.stm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http:///www.VegasHotelBedding.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://static.px.yelp.com/photo/uhrQt43cIGJKSAHztVLjbA/l" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://champaign.il.gegov.com/champaign/estab.cfm?facilityID=2169" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.newyorker.com/reporting/2010/01/11/100111fa_fact_seabrook" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.rodzillareviews.com/2011/03/kaya.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://veganhostess.com/2016/03/25/restaurant-review-apteka-pittsburgh/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://useggrestaurant.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.youtube.com/watch?v=UEJbKLZ7RmM" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.bellagio.com/restaurants/the-buffet.aspx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.youtube.com/watch?v=pR30knJs4Xk
#
# P.S." looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.ktnv.com/news/dirty-dining/dirty-dining-wo-fat-and-seven-more" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.cantinabell.com/cbm/?utm_campaign=Cantina&utm_source=CPC&utm_medium=USM" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.journaldemontreal.com/2015/07/17/rongeurs-a-volonte-au-sushi-999" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://wp.me/p2mHMr-184" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.blogto.com/restaurants/the_gourmet_burger_company" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://local.yahoo.com/info-13236320-klutts-jr-j-vaughn-klutts-property-management-charlotte" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.fourpeaks.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.thecheesecakefactory.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://public.cdpehs.com/NCENVPBL/INSPECTION_VIOLATION/ShowVIOLATIONTable.aspx?INSPECTION=3298534&ESTABLISHMENT=154813&esttst_cty=60." looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.alchemycafe.net/id2.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.mgmgrand.com/pages_html/dining_shibuya.asp" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.complaintsboard.com/?search=sun+devil+auto" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.youtube.com/watch?v=aeixPh5mCI8" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.consumeraffairs.com/misc/massage_envy.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.tripadvisor.com/ShowUserReviews-g45963-d528057-r621202769-Il_Mulino_New_York-Las_Vegas_Nevada.html#" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.superiorcourt.maricopa.gov/docket/CivilCourtCases/caseSearchResults.asp?lastName=&FirstName=&bName=Global+Pharmedica." looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.whatisbrewing.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.yelp.ca/biz_photos/I6oxEn1HT41S2GPrDKPPvA?select=f_htg2D0T-oiohdOMqPCZg" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.yelp.com/biz_photos/cantina-laredo-las-vegas#E_MHz862cJ6Isqczx2lQMQ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.youtube.com/watch?v=yYUdMT3FjlU" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://shop.vegas.com/clubs/calendar.jsp?club=86" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://dorahiers.blogspot.com/2015/09/excited-about-eating-by-ernie-hiers.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.ktnv.com/news/dirty-dining/bachi-burger-blue-martini-and-more-on-dirty-dining" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.ewg.org/foodnews/mobile/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.thrifty.com/BlueChip/BlueChipRewards.aspx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.yelp.com/user_local_photos?userid=h4o8e_Xbca2kXQO_vzOqgg&select=o6i23tiQnEs6Z2KMvx91eg
#
# ah...poke!" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.yelp.ca/events/richmond-hill-uye-meatless-monday-blossom-vegetarian-richmond-hill" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://envapp.maricopa.gov/EnvironmentalHealth/FoodInspection?p=FD-32530&i=4044096" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://showmars.com/menu/Showmars-Nutritional-Information.pdf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://eatinginpittsburgh.com/2010/07/07/ive-got-an-itch-for-kitsch-quiet-storm-in-bloomfield/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.thecamptc.com" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.meetup.com/sushilicious" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://foragerproject.com/products/cashew-milk/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.instagram.com/p/BE60BLCJold/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.yelp.com/biz/bluechipvegas-las-vegas" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.youtube.com/watch?v=q-Rqdgna3Yw
#
# Ciao!" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.thegrilledcheesetruck.com/Pages/menus.aspx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.tradingacademy.com/resources/course-materials/How-The-Markets-Work.aspx?CampaignID=70140000000No28&CampaignCode=ZLWB0NA150812000000_L&utm_medium=web&utm_source=ota-lead&utm_campaign=2012&utm_content=v1" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.ncdentalboard.org/discipline_action.htm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.reviewjournal.com/restaurant-inspection-guide" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.vcahospitals.com/hualapai" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.yelp.com/biz_photos/kareys-kitchen-phoenix?select=SHZJN-BYDlPa74nDjqH2xg#SHZJN-BYDlPa74nDjqH2xg
#
# 2." looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.yelp.com/biz_photos/kareys-kitchen-phoenix?select=Pcxd22BrQ9Ixjgm13149fQ#Pcxd22BrQ9Ixjgm13149fQ
#
# ...
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.vegasbbb.org/bbb_rated_acc_rpt.asp?bbbid=74192&tr=rated&lg=F&ex=15%2C18%2C19%2C26&cc=zz26z26@B2#cch" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.clevelandchildrensmuseum.org/page2.htm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://app.azdhs.gov/ls/online_complaint/LTCComplaint.aspx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://firstusacarpetcleaning.com/aboutus.html." looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://eatitcharlotte.com/2017/05/11/upstream-restaurant/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.post-gazette.com/stories/local/neighborhoods-city/mornings-are-sweet-at-the-pink-house-on-steuben-street-285499/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.snakesandlattes.com/pages/booking" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://electronic-vegas.com/vegas-edm-event-calendar/
#
# https://www.facebook.com/photo.php?fbid=10203891810597249&set=a.10203864061223532.1073741886.1280702242&type=1&theater" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.kpho.com/story/23042384/dirty-dining-aug-1-valley-sushi-bar-has-12-major-violations" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://spoonfulpersuasion.blogspot.com/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.youtube.com/watch?v=g_4X-Yzs7bU" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.bbb.org/consumer-complaints/file-a-complaint/get-started" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.instagram.com/archerandjane/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://www.fda.gov/ForConsumers/ConsumerUpdates/ucm508450.htm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://t.co/u7fHar8R2s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://champaign.il.gegov.com/champaign/estab.cfm?facilityID=1501" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.alliantenergycenter.com/upcoming-events.aspx?ctl=Details&Mid=447&ItemID=1888" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "https://youtu.be/VTk-MRWVZCc" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.foodburgh.com/2010/02/avenue-b/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.yelp.com/user_local_photos?userid=8kskB3QBzO3eQQ1egeasXQ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.lasvegasweekly.com/news/2011/dec/28/oxtail-sauce-cheesecake-sink-your-teeth-2011s-best/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://bit.ly/1mZ9l7J
# http://bit.ly/1meo0Lu
# http://bit.ly/1t4WDZN
# http://bit.ly/1q2412i
# http://bit.ly/1q24kdy" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.spiritcentric.com/montreal-delights-fous-desserts/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.youtube.com/watch?v=q7JWb6n_DvA" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.yelp.com/biz_photos/heavens-cookie-and-creations-las-vegas-2?select=V52AO_nM0rRzljkY-VoqQA#ikwRckwfRFLXpLgmAerg3g" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.mirage.com/entertainment/special-offer-love.aspx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.yelp.com/biz_photos/planet-hollywood-hotel-and-casino-las-vegas-2?select=eZgPKosLmpebFi7j6vIaLg#ikcVFZo89s_prL_OsOrrVQ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.cuyctyengineers.org/subway_tour.htm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.momosushilasvegas.com/home.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.yelp.ca/biz_photos/F8nkAcuCNH-09AWnfv_oWw?select=SFcCQiiUd-JfEtsoorOIHw#RgsGk6HUbFEIEOPoZI4S_w)." looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.batteriesplus.com/store_details/182.aspx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.avenuecalgary.com/City-Life/Calgarys-Most-Haunted-Buildings/." looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.theolivetap.com/medina/index.php" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://friendsofclevelandkennel.com
#
# ." looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://what2eatz.blogspot.com/2011/12/island-style-las-vegas.html" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.winkinglizard.com/data/content/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://www.the-penny-pinchers.com/Category.aspx?srchcity=&srchstore=scramble&srchzip=zip" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/bs4/__init__.py:335: UserWarning: "http://bit.ly/aWqVVJ." looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# x_train: 670000
# x_test: 330000

# %%
x_train = x_train.tolist()
x_test = x_test.tolist()

# %%
len(x_train), len(x_test)
# Out:
# (670000, 330000)

# %%
word_to_idx_dict = {'<unk>':0,'<pad>':1}

for idx,doc in enumerate(x_train) : 
    if idx % 1000 == 0 : print("{}번째 문서 처리 중이며 word_to_idx_dict의 길이는 {}입니다."\
                               .format(idx,len(word_to_idx_dict)))
    for sent in doc[0] : 
        for word in sent : 
            if word not in word_to_idx_dict.keys() :                 
                word_to_idx_dict[word] = len(word_to_idx_dict)
# Out:
# 0번째 문서 처리 중이며 word_to_idx_dict의 길이는 2입니다.
# 1000번째 문서 처리 중이며 word_to_idx_dict의 길이는 6811입니다.
# 2000번째 문서 처리 중이며 word_to_idx_dict의 길이는 9736입니다.
# 3000번째 문서 처리 중이며 word_to_idx_dict의 길이는 12154입니다.
# 4000번째 문서 처리 중이며 word_to_idx_dict의 길이는 13990입니다.
# 5000번째 문서 처리 중이며 word_to_idx_dict의 길이는 15810입니다.
# 6000번째 문서 처리 중이며 word_to_idx_dict의 길이는 17216입니다.
# 7000번째 문서 처리 중이며 word_to_idx_dict의 길이는 18832입니다.
# 8000번째 문서 처리 중이며 word_to_idx_dict의 길이는 20071입니다.
# 9000번째 문서 처리 중이며 word_to_idx_dict의 길이는 21231입니다.
# 10000번째 문서 처리 중이며 word_to_idx_dict의 길이는 22394입니다.
# 11000번째 문서 처리 중이며 word_to_idx_dict의 길이는 23517입니다.
# 12000번째 문서 처리 중이며 word_to_idx_dict의 길이는 24557입니다.
# 13000번째 문서 처리 중이며 word_to_idx_dict의 길이는 25641입니다.
# 14000번째 문서 처리 중이며 word_to_idx_dict의 길이는 26567입니다.
# 15000번째 문서 처리 중이며 word_to_idx_dict의 길이는 27407입니다.
# 16000번째 문서 처리 중이며 word_to_idx_dict의 길이는 28208입니다.
# 17000번째 문서 처리 중이며 word_to_idx_dict의 길이는 29156입니다.
# 18000번째 문서 처리 중이며 word_to_idx_dict의 길이는 29876입니다.
# 19000번째 문서 처리 중이며 word_to_idx_dict의 길이는 30665입니다.
# 20000번째 문서 처리 중이며 word_to_idx_dict의 길이는 31315입니다.
# 21000번째 문서 처리 중이며 word_to_idx_dict의 길이는 32150입니다.
# 22000번째 문서 처리 중이며 word_to_idx_dict의 길이는 32914입니다.
# 23000번째 문서 처리 중이며 word_to_idx_dict의 길이는 33615입니다.
# 24000번째 문서 처리 중이며 word_to_idx_dict의 길이는 34344입니다.
# 25000번째 문서 처리 중이며 word_to_idx_dict의 길이는 35013입니다.
# 26000번째 문서 처리 중이며 word_to_idx_dict의 길이는 35604입니다.
# 27000번째 문서 처리 중이며 word_to_idx_dict의 길이는 36184입니다.
# 28000번째 문서 처리 중이며 word_to_idx_dict의 길이는 36826입니다.
# 29000번째 문서 처리 중이며 word_to_idx_dict의 길이는 37540입니다.
# 30000번째 문서 처리 중이며 word_to_idx_dict의 길이는 38157입니다.
# 31000번째 문서 처리 중이며 word_to_idx_dict의 길이는 38670입니다.
# 32000번째 문서 처리 중이며 word_to_idx_dict의 길이는 39266입니다.
# 33000번째 문서 처리 중이며 word_to_idx_dict의 길이는 39822입니다.
# 34000번째 문서 처리 중이며 word_to_idx_dict의 길이는 40389입니다.
# 35000번째 문서 처리 중이며 word_to_idx_dict의 길이는 40958입니다.
# 36000번째 문서 처리 중이며 word_to_idx_dict의 길이는 41502입니다.
# 37000번째 문서 처리 중이며 word_to_idx_dict의 길이는 42055입니다.
# 38000번째 문서 처리 중이며 word_to_idx_dict의 길이는 42661입니다.
# 39000번째 문서 처리 중이며 word_to_idx_dict의 길이는 43210입니다.
# 40000번째 문서 처리 중이며 word_to_idx_dict의 길이는 43698입니다.
# 41000번째 문서 처리 중이며 word_to_idx_dict의 길이는 44217입니다.
# 42000번째 문서 처리 중이며 word_to_idx_dict의 길이는 44691입니다.
# 43000번째 문서 처리 중이며 word_to_idx_dict의 길이는 45211입니다.
# 44000번째 문서 처리 중이며 word_to_idx_dict의 길이는 45684입니다.
# 45000번째 문서 처리 중이며 word_to_idx_dict의 길이는 46140입니다.
# 46000번째 문서 처리 중이며 word_to_idx_dict의 길이는 46643입니다.
# 47000번째 문서 처리 중이며 word_to_idx_dict의 길이는 47186입니다.
# 48000번째 문서 처리 중이며 word_to_idx_dict의 길이는 47722입니다.
# 49000번째 문서 처리 중이며 word_to_idx_dict의 길이는 48219입니다.
# 50000번째 문서 처리 중이며 word_to_idx_dict의 길이는 48708입니다.
# 51000번째 문서 처리 중이며 word_to_idx_dict의 길이는 49169입니다.
# 52000번째 문서 처리 중이며 word_to_idx_dict의 길이는 49596입니다.
# 53000번째 문서 처리 중이며 word_to_idx_dict의 길이는 50093입니다.
# 54000번째 문서 처리 중이며 word_to_idx_dict의 길이는 50525입니다.
# 55000번째 문서 처리 중이며 word_to_idx_dict의 길이는 50960입니다.
# 56000번째 문서 처리 중이며 word_to_idx_dict의 길이는 51375입니다.
# 57000번째 문서 처리 중이며 word_to_idx_dict의 길이는 51775입니다.
# 58000번째 문서 처리 중이며 word_to_idx_dict의 길이는 52155입니다.
# 59000번째 문서 처리 중이며 word_to_idx_dict의 길이는 52577입니다.
# 60000번째 문서 처리 중이며 word_to_idx_dict의 길이는 52949입니다.
# 61000번째 문서 처리 중이며 word_to_idx_dict의 길이는 53357입니다.
# 62000번째 문서 처리 중이며 word_to_idx_dict의 길이는 53749입니다.
# 63000번째 문서 처리 중이며 word_to_idx_dict의 길이는 54129입니다.
# 64000번째 문서 처리 중이며 word_to_idx_dict의 길이는 54562입니다.
# 65000번째 문서 처리 중이며 word_to_idx_dict의 길이는 54952입니다.
# 66000번째 문서 처리 중이며 word_to_idx_dict의 길이는 55350입니다.
# 67000번째 문서 처리 중이며 word_to_idx_dict의 길이는 55738입니다.
# 68000번째 문서 처리 중이며 word_to_idx_dict의 길이는 56095입니다.
# 69000번째 문서 처리 중이며 word_to_idx_dict의 길이는 56512입니다.
# 70000번째 문서 처리 중이며 word_to_idx_dict의 길이는 56896입니다.
# 71000번째 문서 처리 중이며 word_to_idx_dict의 길이는 57274입니다.
# 72000번째 문서 처리 중이며 word_to_idx_dict의 길이는 57640입니다.
# 73000번째 문서 처리 중이며 word_to_idx_dict의 길이는 58000입니다.
# 74000번째 문서 처리 중이며 word_to_idx_dict의 길이는 58315입니다.
# 75000번째 문서 처리 중이며 word_to_idx_dict의 길이는 58680입니다.
# 76000번째 문서 처리 중이며 word_to_idx_dict의 길이는 59080입니다.
# 77000번째 문서 처리 중이며 word_to_idx_dict의 길이는 59454입니다.
# 78000번째 문서 처리 중이며 word_to_idx_dict의 길이는 59836입니다.
# 79000번째 문서 처리 중이며 word_to_idx_dict의 길이는 60193입니다.
# 80000번째 문서 처리 중이며 word_to_idx_dict의 길이는 60518입니다.
# 81000번째 문서 처리 중이며 word_to_idx_dict의 길이는 60864입니다.
# 82000번째 문서 처리 중이며 word_to_idx_dict의 길이는 61259입니다.
# 83000번째 문서 처리 중이며 word_to_idx_dict의 길이는 61681입니다.
# 84000번째 문서 처리 중이며 word_to_idx_dict의 길이는 62073입니다.
# 85000번째 문서 처리 중이며 word_to_idx_dict의 길이는 62424입니다.
# 86000번째 문서 처리 중이며 word_to_idx_dict의 길이는 62784입니다.
# 87000번째 문서 처리 중이며 word_to_idx_dict의 길이는 63097입니다.
# 88000번째 문서 처리 중이며 word_to_idx_dict의 길이는 63456입니다.
# 89000번째 문서 처리 중이며 word_to_idx_dict의 길이는 63824입니다.
# 90000번째 문서 처리 중이며 word_to_idx_dict의 길이는 64145입니다.
# 91000번째 문서 처리 중이며 word_to_idx_dict의 길이는 64475입니다.
# 92000번째 문서 처리 중이며 word_to_idx_dict의 길이는 64832입니다.
# 93000번째 문서 처리 중이며 word_to_idx_dict의 길이는 65130입니다.
# 94000번째 문서 처리 중이며 word_to_idx_dict의 길이는 65446입니다.
# 95000번째 문서 처리 중이며 word_to_idx_dict의 길이는 65847입니다.
# 96000번째 문서 처리 중이며 word_to_idx_dict의 길이는 66189입니다.
# 97000번째 문서 처리 중이며 word_to_idx_dict의 길이는 66501입니다.
# 98000번째 문서 처리 중이며 word_to_idx_dict의 길이는 66831입니다.
# 99000번째 문서 처리 중이며 word_to_idx_dict의 길이는 67154입니다.
# 100000번째 문서 처리 중이며 word_to_idx_dict의 길이는 67491입니다.
# 101000번째 문서 처리 중이며 word_to_idx_dict의 길이는 67820입니다.
# 102000번째 문서 처리 중이며 word_to_idx_dict의 길이는 68190입니다.
# 103000번째 문서 처리 중이며 word_to_idx_dict의 길이는 68470입니다.
# 104000번째 문서 처리 중이며 word_to_idx_dict의 길이는 68787입니다.
# 105000번째 문서 처리 중이며 word_to_idx_dict의 길이는 69067입니다.
# 106000번째 문서 처리 중이며 word_to_idx_dict의 길이는 69358입니다.
# 107000번째 문서 처리 중이며 word_to_idx_dict의 길이는 69724입니다.
# 108000번째 문서 처리 중이며 word_to_idx_dict의 길이는 70013입니다.
# 109000번째 문서 처리 중이며 word_to_idx_dict의 길이는 70289입니다.
# 110000번째 문서 처리 중이며 word_to_idx_dict의 길이는 70586입니다.
# 111000번째 문서 처리 중이며 word_to_idx_dict의 길이는 70883입니다.
# 112000번째 문서 처리 중이며 word_to_idx_dict의 길이는 71180입니다.
# 113000번째 문서 처리 중이며 word_to_idx_dict의 길이는 71517입니다.
# 114000번째 문서 처리 중이며 word_to_idx_dict의 길이는 71830입니다.
# 115000번째 문서 처리 중이며 word_to_idx_dict의 길이는 72145입니다.
# 116000번째 문서 처리 중이며 word_to_idx_dict의 길이는 72390입니다.
# 117000번째 문서 처리 중이며 word_to_idx_dict의 길이는 72722입니다.
# 118000번째 문서 처리 중이며 word_to_idx_dict의 길이는 73017입니다.
# 119000번째 문서 처리 중이며 word_to_idx_dict의 길이는 73297입니다.
# 120000번째 문서 처리 중이며 word_to_idx_dict의 길이는 73626입니다.
# 121000번째 문서 처리 중이며 word_to_idx_dict의 길이는 73931입니다.
# 122000번째 문서 처리 중이며 word_to_idx_dict의 길이는 74210입니다.
# 123000번째 문서 처리 중이며 word_to_idx_dict의 길이는 74544입니다.
# 124000번째 문서 처리 중이며 word_to_idx_dict의 길이는 74829입니다.
# 125000번째 문서 처리 중이며 word_to_idx_dict의 길이는 75137입니다.
# 126000번째 문서 처리 중이며 word_to_idx_dict의 길이는 75423입니다.
# 127000번째 문서 처리 중이며 word_to_idx_dict의 길이는 75652입니다.
# 128000번째 문서 처리 중이며 word_to_idx_dict의 길이는 75932입니다.
# 129000번째 문서 처리 중이며 word_to_idx_dict의 길이는 76233입니다.
# 130000번째 문서 처리 중이며 word_to_idx_dict의 길이는 76505입니다.
# 131000번째 문서 처리 중이며 word_to_idx_dict의 길이는 76791입니다.
# 132000번째 문서 처리 중이며 word_to_idx_dict의 길이는 77078입니다.
# 133000번째 문서 처리 중이며 word_to_idx_dict의 길이는 77364입니다.
# 134000번째 문서 처리 중이며 word_to_idx_dict의 길이는 77629입니다.
# 135000번째 문서 처리 중이며 word_to_idx_dict의 길이는 77909입니다.
# 136000번째 문서 처리 중이며 word_to_idx_dict의 길이는 78180입니다.
# 137000번째 문서 처리 중이며 word_to_idx_dict의 길이는 78479입니다.
# 138000번째 문서 처리 중이며 word_to_idx_dict의 길이는 78768입니다.
# 139000번째 문서 처리 중이며 word_to_idx_dict의 길이는 79071입니다.
# 140000번째 문서 처리 중이며 word_to_idx_dict의 길이는 79358입니다.
# 141000번째 문서 처리 중이며 word_to_idx_dict의 길이는 79597입니다.
# 142000번째 문서 처리 중이며 word_to_idx_dict의 길이는 79846입니다.
# 143000번째 문서 처리 중이며 word_to_idx_dict의 길이는 80146입니다.
# 144000번째 문서 처리 중이며 word_to_idx_dict의 길이는 80425입니다.
# 145000번째 문서 처리 중이며 word_to_idx_dict의 길이는 80715입니다.
# 146000번째 문서 처리 중이며 word_to_idx_dict의 길이는 80997입니다.
# 147000번째 문서 처리 중이며 word_to_idx_dict의 길이는 81339입니다.
# 148000번째 문서 처리 중이며 word_to_idx_dict의 길이는 81607입니다.
# 149000번째 문서 처리 중이며 word_to_idx_dict의 길이는 81892입니다.
# 150000번째 문서 처리 중이며 word_to_idx_dict의 길이는 82175입니다.
# 151000번째 문서 처리 중이며 word_to_idx_dict의 길이는 82414입니다.
# 152000번째 문서 처리 중이며 word_to_idx_dict의 길이는 82671입니다.
# 153000번째 문서 처리 중이며 word_to_idx_dict의 길이는 82966입니다.
# 154000번째 문서 처리 중이며 word_to_idx_dict의 길이는 83196입니다.
# 155000번째 문서 처리 중이며 word_to_idx_dict의 길이는 83460입니다.
# 156000번째 문서 처리 중이며 word_to_idx_dict의 길이는 83718입니다.
# 157000번째 문서 처리 중이며 word_to_idx_dict의 길이는 83989입니다.
# 158000번째 문서 처리 중이며 word_to_idx_dict의 길이는 84240입니다.
# 159000번째 문서 처리 중이며 word_to_idx_dict의 길이는 84536입니다.
# 160000번째 문서 처리 중이며 word_to_idx_dict의 길이는 84811입니다.
# 161000번째 문서 처리 중이며 word_to_idx_dict의 길이는 85049입니다.
# 162000번째 문서 처리 중이며 word_to_idx_dict의 길이는 85282입니다.
# 163000번째 문서 처리 중이며 word_to_idx_dict의 길이는 85521입니다.
# 164000번째 문서 처리 중이며 word_to_idx_dict의 길이는 85733입니다.
# 165000번째 문서 처리 중이며 word_to_idx_dict의 길이는 85953입니다.
# 166000번째 문서 처리 중이며 word_to_idx_dict의 길이는 86195입니다.
# 167000번째 문서 처리 중이며 word_to_idx_dict의 길이는 86444입니다.
# 168000번째 문서 처리 중이며 word_to_idx_dict의 길이는 86737입니다.
# 169000번째 문서 처리 중이며 word_to_idx_dict의 길이는 86984입니다.
# 170000번째 문서 처리 중이며 word_to_idx_dict의 길이는 87205입니다.
# 171000번째 문서 처리 중이며 word_to_idx_dict의 길이는 87465입니다.
# 172000번째 문서 처리 중이며 word_to_idx_dict의 길이는 87679입니다.
# 173000번째 문서 처리 중이며 word_to_idx_dict의 길이는 87916입니다.
# 174000번째 문서 처리 중이며 word_to_idx_dict의 길이는 88173입니다.
# 175000번째 문서 처리 중이며 word_to_idx_dict의 길이는 88387입니다.
# 176000번째 문서 처리 중이며 word_to_idx_dict의 길이는 88656입니다.
# 177000번째 문서 처리 중이며 word_to_idx_dict의 길이는 88896입니다.
# 178000번째 문서 처리 중이며 word_to_idx_dict의 길이는 89128입니다.
# 179000번째 문서 처리 중이며 word_to_idx_dict의 길이는 89400입니다.
# 180000번째 문서 처리 중이며 word_to_idx_dict의 길이는 89623입니다.
# 181000번째 문서 처리 중이며 word_to_idx_dict의 길이는 89865입니다.
# 182000번째 문서 처리 중이며 word_to_idx_dict의 길이는 90079입니다.
# 183000번째 문서 처리 중이며 word_to_idx_dict의 길이는 90306입니다.
# 184000번째 문서 처리 중이며 word_to_idx_dict의 길이는 90517입니다.
# 185000번째 문서 처리 중이며 word_to_idx_dict의 길이는 90744입니다.
# 186000번째 문서 처리 중이며 word_to_idx_dict의 길이는 90960입니다.
# 187000번째 문서 처리 중이며 word_to_idx_dict의 길이는 91158입니다.
# 188000번째 문서 처리 중이며 word_to_idx_dict의 길이는 91421입니다.
# 189000번째 문서 처리 중이며 word_to_idx_dict의 길이는 91627입니다.
# 190000번째 문서 처리 중이며 word_to_idx_dict의 길이는 91889입니다.
# 191000번째 문서 처리 중이며 word_to_idx_dict의 길이는 92107입니다.
# 192000번째 문서 처리 중이며 word_to_idx_dict의 길이는 92365입니다.
# 193000번째 문서 처리 중이며 word_to_idx_dict의 길이는 92574입니다.
# 194000번째 문서 처리 중이며 word_to_idx_dict의 길이는 92789입니다.
# 195000번째 문서 처리 중이며 word_to_idx_dict의 길이는 93019입니다.
# 196000번째 문서 처리 중이며 word_to_idx_dict의 길이는 93228입니다.
# 197000번째 문서 처리 중이며 word_to_idx_dict의 길이는 93435입니다.
# 198000번째 문서 처리 중이며 word_to_idx_dict의 길이는 93670입니다.
# 199000번째 문서 처리 중이며 word_to_idx_dict의 길이는 93915입니다.
# 200000번째 문서 처리 중이며 word_to_idx_dict의 길이는 94150입니다.
# 201000번째 문서 처리 중이며 word_to_idx_dict의 길이는 94354입니다.
# 202000번째 문서 처리 중이며 word_to_idx_dict의 길이는 94557입니다.
# 203000번째 문서 처리 중이며 word_to_idx_dict의 길이는 94795입니다.
# 204000번째 문서 처리 중이며 word_to_idx_dict의 길이는 95045입니다.
# 205000번째 문서 처리 중이며 word_to_idx_dict의 길이는 95276입니다.
# 206000번째 문서 처리 중이며 word_to_idx_dict의 길이는 95499입니다.
# 207000번째 문서 처리 중이며 word_to_idx_dict의 길이는 95724입니다.
# 208000번째 문서 처리 중이며 word_to_idx_dict의 길이는 95989입니다.
# 209000번째 문서 처리 중이며 word_to_idx_dict의 길이는 96228입니다.
# 210000번째 문서 처리 중이며 word_to_idx_dict의 길이는 96491입니다.
# 211000번째 문서 처리 중이며 word_to_idx_dict의 길이는 96717입니다.
# 212000번째 문서 처리 중이며 word_to_idx_dict의 길이는 96938입니다.
# 213000번째 문서 처리 중이며 word_to_idx_dict의 길이는 97148입니다.
# 214000번째 문서 처리 중이며 word_to_idx_dict의 길이는 97361입니다.
# 215000번째 문서 처리 중이며 word_to_idx_dict의 길이는 97582입니다.
# 216000번째 문서 처리 중이며 word_to_idx_dict의 길이는 97791입니다.
# 217000번째 문서 처리 중이며 word_to_idx_dict의 길이는 98004입니다.
# 218000번째 문서 처리 중이며 word_to_idx_dict의 길이는 98219입니다.
# 219000번째 문서 처리 중이며 word_to_idx_dict의 길이는 98480입니다.
# 220000번째 문서 처리 중이며 word_to_idx_dict의 길이는 98667입니다.
# 221000번째 문서 처리 중이며 word_to_idx_dict의 길이는 98870입니다.
# 222000번째 문서 처리 중이며 word_to_idx_dict의 길이는 99086입니다.
# 223000번째 문서 처리 중이며 word_to_idx_dict의 길이는 99283입니다.
# 224000번째 문서 처리 중이며 word_to_idx_dict의 길이는 99527입니다.
# 225000번째 문서 처리 중이며 word_to_idx_dict의 길이는 99762입니다.
# 226000번째 문서 처리 중이며 word_to_idx_dict의 길이는 99962입니다.
# 227000번째 문서 처리 중이며 word_to_idx_dict의 길이는 100183입니다.
# 228000번째 문서 처리 중이며 word_to_idx_dict의 길이는 100398입니다.
# 229000번째 문서 처리 중이며 word_to_idx_dict의 길이는 100593입니다.
# 230000번째 문서 처리 중이며 word_to_idx_dict의 길이는 100790입니다.
# 231000번째 문서 처리 중이며 word_to_idx_dict의 길이는 101047입니다.
# 232000번째 문서 처리 중이며 word_to_idx_dict의 길이는 101235입니다.
# 233000번째 문서 처리 중이며 word_to_idx_dict의 길이는 101409입니다.
# 234000번째 문서 처리 중이며 word_to_idx_dict의 길이는 101649입니다.
# 235000번째 문서 처리 중이며 word_to_idx_dict의 길이는 101845입니다.
# 236000번째 문서 처리 중이며 word_to_idx_dict의 길이는 102072입니다.
# 237000번째 문서 처리 중이며 word_to_idx_dict의 길이는 102301입니다.
# 238000번째 문서 처리 중이며 word_to_idx_dict의 길이는 102490입니다.
# 239000번째 문서 처리 중이며 word_to_idx_dict의 길이는 102735입니다.
# 240000번째 문서 처리 중이며 word_to_idx_dict의 길이는 102942입니다.
# 241000번째 문서 처리 중이며 word_to_idx_dict의 길이는 103097입니다.
# 242000번째 문서 처리 중이며 word_to_idx_dict의 길이는 103311입니다.
# 243000번째 문서 처리 중이며 word_to_idx_dict의 길이는 103525입니다.
# 244000번째 문서 처리 중이며 word_to_idx_dict의 길이는 103714입니다.
# 245000번째 문서 처리 중이며 word_to_idx_dict의 길이는 103951입니다.
# 246000번째 문서 처리 중이며 word_to_idx_dict의 길이는 104151입니다.
# 247000번째 문서 처리 중이며 word_to_idx_dict의 길이는 104340입니다.
# 248000번째 문서 처리 중이며 word_to_idx_dict의 길이는 104510입니다.
# 249000번째 문서 처리 중이며 word_to_idx_dict의 길이는 104682입니다.
# 250000번째 문서 처리 중이며 word_to_idx_dict의 길이는 104903입니다.
# 251000번째 문서 처리 중이며 word_to_idx_dict의 길이는 105076입니다.
# 252000번째 문서 처리 중이며 word_to_idx_dict의 길이는 105251입니다.
# 253000번째 문서 처리 중이며 word_to_idx_dict의 길이는 105452입니다.
# 254000번째 문서 처리 중이며 word_to_idx_dict의 길이는 105660입니다.
# 255000번째 문서 처리 중이며 word_to_idx_dict의 길이는 105841입니다.
# 256000번째 문서 처리 중이며 word_to_idx_dict의 길이는 106021입니다.
# 257000번째 문서 처리 중이며 word_to_idx_dict의 길이는 106221입니다.
# 258000번째 문서 처리 중이며 word_to_idx_dict의 길이는 106451입니다.
# 259000번째 문서 처리 중이며 word_to_idx_dict의 길이는 106676입니다.
# 260000번째 문서 처리 중이며 word_to_idx_dict의 길이는 106887입니다.
# 261000번째 문서 처리 중이며 word_to_idx_dict의 길이는 107071입니다.
# 262000번째 문서 처리 중이며 word_to_idx_dict의 길이는 107253입니다.
# 263000번째 문서 처리 중이며 word_to_idx_dict의 길이는 107457입니다.
# 264000번째 문서 처리 중이며 word_to_idx_dict의 길이는 107625입니다.
# 265000번째 문서 처리 중이며 word_to_idx_dict의 길이는 107818입니다.
# 266000번째 문서 처리 중이며 word_to_idx_dict의 길이는 108026입니다.
# 267000번째 문서 처리 중이며 word_to_idx_dict의 길이는 108235입니다.
# 268000번째 문서 처리 중이며 word_to_idx_dict의 길이는 108453입니다.
# 269000번째 문서 처리 중이며 word_to_idx_dict의 길이는 108648입니다.
# 270000번째 문서 처리 중이며 word_to_idx_dict의 길이는 108846입니다.
# 271000번째 문서 처리 중이며 word_to_idx_dict의 길이는 109008입니다.
# 272000번째 문서 처리 중이며 word_to_idx_dict의 길이는 109223입니다.
# 273000번째 문서 처리 중이며 word_to_idx_dict의 길이는 109420입니다.
# 274000번째 문서 처리 중이며 word_to_idx_dict의 길이는 109606입니다.
# 275000번째 문서 처리 중이며 word_to_idx_dict의 길이는 109842입니다.
# 276000번째 문서 처리 중이며 word_to_idx_dict의 길이는 110054입니다.
# 277000번째 문서 처리 중이며 word_to_idx_dict의 길이는 110242입니다.
# 278000번째 문서 처리 중이며 word_to_idx_dict의 길이는 110441입니다.
# 279000번째 문서 처리 중이며 word_to_idx_dict의 길이는 110595입니다.
# 280000번째 문서 처리 중이며 word_to_idx_dict의 길이는 110791입니다.
# 281000번째 문서 처리 중이며 word_to_idx_dict의 길이는 110978입니다.
# 282000번째 문서 처리 중이며 word_to_idx_dict의 길이는 111170입니다.
# 283000번째 문서 처리 중이며 word_to_idx_dict의 길이는 111331입니다.
# 284000번째 문서 처리 중이며 word_to_idx_dict의 길이는 111514입니다.
# 285000번째 문서 처리 중이며 word_to_idx_dict의 길이는 111687입니다.
# 286000번째 문서 처리 중이며 word_to_idx_dict의 길이는 111863입니다.
# 287000번째 문서 처리 중이며 word_to_idx_dict의 길이는 112039입니다.
# 288000번째 문서 처리 중이며 word_to_idx_dict의 길이는 112208입니다.
# 289000번째 문서 처리 중이며 word_to_idx_dict의 길이는 112419입니다.
# 290000번째 문서 처리 중이며 word_to_idx_dict의 길이는 112616입니다.
# 291000번째 문서 처리 중이며 word_to_idx_dict의 길이는 112804입니다.
# 292000번째 문서 처리 중이며 word_to_idx_dict의 길이는 112980입니다.
# 293000번째 문서 처리 중이며 word_to_idx_dict의 길이는 113173입니다.
# 294000번째 문서 처리 중이며 word_to_idx_dict의 길이는 113382입니다.
# 295000번째 문서 처리 중이며 word_to_idx_dict의 길이는 113536입니다.
# 296000번째 문서 처리 중이며 word_to_idx_dict의 길이는 113750입니다.
# 297000번째 문서 처리 중이며 word_to_idx_dict의 길이는 113942입니다.
# 298000번째 문서 처리 중이며 word_to_idx_dict의 길이는 114120입니다.
# 299000번째 문서 처리 중이며 word_to_idx_dict의 길이는 114307입니다.
# 300000번째 문서 처리 중이며 word_to_idx_dict의 길이는 114476입니다.
# 301000번째 문서 처리 중이며 word_to_idx_dict의 길이는 114677입니다.
# 302000번째 문서 처리 중이며 word_to_idx_dict의 길이는 114895입니다.
# 303000번째 문서 처리 중이며 word_to_idx_dict의 길이는 115065입니다.
# 304000번째 문서 처리 중이며 word_to_idx_dict의 길이는 115246입니다.
# 305000번째 문서 처리 중이며 word_to_idx_dict의 길이는 115449입니다.
# 306000번째 문서 처리 중이며 word_to_idx_dict의 길이는 115635입니다.
# 307000번째 문서 처리 중이며 word_to_idx_dict의 길이는 115826입니다.
# 308000번째 문서 처리 중이며 word_to_idx_dict의 길이는 116010입니다.
# 309000번째 문서 처리 중이며 word_to_idx_dict의 길이는 116167입니다.
# 310000번째 문서 처리 중이며 word_to_idx_dict의 길이는 116355입니다.
# 311000번째 문서 처리 중이며 word_to_idx_dict의 길이는 116546입니다.
# 312000번째 문서 처리 중이며 word_to_idx_dict의 길이는 116752입니다.
# 313000번째 문서 처리 중이며 word_to_idx_dict의 길이는 116935입니다.
# 314000번째 문서 처리 중이며 word_to_idx_dict의 길이는 117104입니다.
# 315000번째 문서 처리 중이며 word_to_idx_dict의 길이는 117293입니다.
# 316000번째 문서 처리 중이며 word_to_idx_dict의 길이는 117488입니다.
# 317000번째 문서 처리 중이며 word_to_idx_dict의 길이는 117685입니다.
# 318000번째 문서 처리 중이며 word_to_idx_dict의 길이는 117875입니다.
# 319000번째 문서 처리 중이며 word_to_idx_dict의 길이는 118062입니다.
# 320000번째 문서 처리 중이며 word_to_idx_dict의 길이는 118257입니다.
# 321000번째 문서 처리 중이며 word_to_idx_dict의 길이는 118413입니다.
# 322000번째 문서 처리 중이며 word_to_idx_dict의 길이는 118615입니다.
# 323000번째 문서 처리 중이며 word_to_idx_dict의 길이는 118805입니다.
# 324000번째 문서 처리 중이며 word_to_idx_dict의 길이는 118953입니다.
# 325000번째 문서 처리 중이며 word_to_idx_dict의 길이는 119099입니다.
# 326000번째 문서 처리 중이며 word_to_idx_dict의 길이는 119249입니다.
# 327000번째 문서 처리 중이며 word_to_idx_dict의 길이는 119392입니다.
# 328000번째 문서 처리 중이며 word_to_idx_dict의 길이는 119572입니다.
# 329000번째 문서 처리 중이며 word_to_idx_dict의 길이는 119758입니다.
# 330000번째 문서 처리 중이며 word_to_idx_dict의 길이는 119934입니다.
# 331000번째 문서 처리 중이며 word_to_idx_dict의 길이는 120135입니다.
# 332000번째 문서 처리 중이며 word_to_idx_dict의 길이는 120313입니다.
# 333000번째 문서 처리 중이며 word_to_idx_dict의 길이는 120468입니다.
# 334000번째 문서 처리 중이며 word_to_idx_dict의 길이는 120648입니다.
# 335000번째 문서 처리 중이며 word_to_idx_dict의 길이는 120807입니다.
# 336000번째 문서 처리 중이며 word_to_idx_dict의 길이는 120976입니다.
# 337000번째 문서 처리 중이며 word_to_idx_dict의 길이는 121150입니다.
# 338000번째 문서 처리 중이며 word_to_idx_dict의 길이는 121329입니다.
# 339000번째 문서 처리 중이며 word_to_idx_dict의 길이는 121496입니다.
# 340000번째 문서 처리 중이며 word_to_idx_dict의 길이는 121658입니다.
# 341000번째 문서 처리 중이며 word_to_idx_dict의 길이는 121832입니다.
# 342000번째 문서 처리 중이며 word_to_idx_dict의 길이는 122019입니다.
# 343000번째 문서 처리 중이며 word_to_idx_dict의 길이는 122197입니다.
# 344000번째 문서 처리 중이며 word_to_idx_dict의 길이는 122359입니다.
# 345000번째 문서 처리 중이며 word_to_idx_dict의 길이는 122538입니다.
# 346000번째 문서 처리 중이며 word_to_idx_dict의 길이는 122717입니다.
# 347000번째 문서 처리 중이며 word_to_idx_dict의 길이는 122872입니다.
# 348000번째 문서 처리 중이며 word_to_idx_dict의 길이는 123030입니다.
# 349000번째 문서 처리 중이며 word_to_idx_dict의 길이는 123215입니다.
# 350000번째 문서 처리 중이며 word_to_idx_dict의 길이는 123367입니다.
# 351000번째 문서 처리 중이며 word_to_idx_dict의 길이는 123550입니다.
# 352000번째 문서 처리 중이며 word_to_idx_dict의 길이는 123740입니다.
# 353000번째 문서 처리 중이며 word_to_idx_dict의 길이는 123928입니다.
# 354000번째 문서 처리 중이며 word_to_idx_dict의 길이는 124155입니다.
# 355000번째 문서 처리 중이며 word_to_idx_dict의 길이는 124312입니다.
# 356000번째 문서 처리 중이며 word_to_idx_dict의 길이는 124482입니다.
# 357000번째 문서 처리 중이며 word_to_idx_dict의 길이는 124642입니다.
# 358000번째 문서 처리 중이며 word_to_idx_dict의 길이는 124785입니다.
# 359000번째 문서 처리 중이며 word_to_idx_dict의 길이는 124952입니다.
# 360000번째 문서 처리 중이며 word_to_idx_dict의 길이는 125115입니다.
# 361000번째 문서 처리 중이며 word_to_idx_dict의 길이는 125280입니다.
# 362000번째 문서 처리 중이며 word_to_idx_dict의 길이는 125453입니다.
# 363000번째 문서 처리 중이며 word_to_idx_dict의 길이는 125606입니다.
# 364000번째 문서 처리 중이며 word_to_idx_dict의 길이는 125786입니다.
# 365000번째 문서 처리 중이며 word_to_idx_dict의 길이는 125949입니다.
# 366000번째 문서 처리 중이며 word_to_idx_dict의 길이는 126121입니다.
# 367000번째 문서 처리 중이며 word_to_idx_dict의 길이는 126309입니다.
# 368000번째 문서 처리 중이며 word_to_idx_dict의 길이는 126452입니다.
# 369000번째 문서 처리 중이며 word_to_idx_dict의 길이는 126599입니다.
# 370000번째 문서 처리 중이며 word_to_idx_dict의 길이는 126754입니다.
# 371000번째 문서 처리 중이며 word_to_idx_dict의 길이는 126953입니다.
# 372000번째 문서 처리 중이며 word_to_idx_dict의 길이는 127104입니다.
# 373000번째 문서 처리 중이며 word_to_idx_dict의 길이는 127271입니다.
# 374000번째 문서 처리 중이며 word_to_idx_dict의 길이는 127455입니다.
# 375000번째 문서 처리 중이며 word_to_idx_dict의 길이는 127624입니다.
# 376000번째 문서 처리 중이며 word_to_idx_dict의 길이는 127801입니다.
# 377000번째 문서 처리 중이며 word_to_idx_dict의 길이는 127955입니다.
# 378000번째 문서 처리 중이며 word_to_idx_dict의 길이는 128122입니다.
# 379000번째 문서 처리 중이며 word_to_idx_dict의 길이는 128273입니다.
# 380000번째 문서 처리 중이며 word_to_idx_dict의 길이는 128468입니다.
# 381000번째 문서 처리 중이며 word_to_idx_dict의 길이는 128633입니다.
# 382000번째 문서 처리 중이며 word_to_idx_dict의 길이는 128811입니다.
# 383000번째 문서 처리 중이며 word_to_idx_dict의 길이는 128975입니다.
# 384000번째 문서 처리 중이며 word_to_idx_dict의 길이는 129135입니다.
# 385000번째 문서 처리 중이며 word_to_idx_dict의 길이는 129289입니다.
# 386000번째 문서 처리 중이며 word_to_idx_dict의 길이는 129462입니다.
# 387000번째 문서 처리 중이며 word_to_idx_dict의 길이는 129634입니다.
# 388000번째 문서 처리 중이며 word_to_idx_dict의 길이는 129794입니다.
# 389000번째 문서 처리 중이며 word_to_idx_dict의 길이는 129964입니다.
# 390000번째 문서 처리 중이며 word_to_idx_dict의 길이는 130114입니다.
# 391000번째 문서 처리 중이며 word_to_idx_dict의 길이는 130291입니다.
# 392000번째 문서 처리 중이며 word_to_idx_dict의 길이는 130474입니다.
# 393000번째 문서 처리 중이며 word_to_idx_dict의 길이는 130642입니다.
# 394000번째 문서 처리 중이며 word_to_idx_dict의 길이는 130796입니다.
# 395000번째 문서 처리 중이며 word_to_idx_dict의 길이는 130967입니다.
# 396000번째 문서 처리 중이며 word_to_idx_dict의 길이는 131121입니다.
# 397000번째 문서 처리 중이며 word_to_idx_dict의 길이는 131296입니다.
# 398000번째 문서 처리 중이며 word_to_idx_dict의 길이는 131450입니다.
# 399000번째 문서 처리 중이며 word_to_idx_dict의 길이는 131605입니다.
# 400000번째 문서 처리 중이며 word_to_idx_dict의 길이는 131763입니다.
# 401000번째 문서 처리 중이며 word_to_idx_dict의 길이는 131923입니다.
# 402000번째 문서 처리 중이며 word_to_idx_dict의 길이는 132061입니다.
# 403000번째 문서 처리 중이며 word_to_idx_dict의 길이는 132222입니다.
# 404000번째 문서 처리 중이며 word_to_idx_dict의 길이는 132377입니다.
# 405000번째 문서 처리 중이며 word_to_idx_dict의 길이는 132540입니다.
# 406000번째 문서 처리 중이며 word_to_idx_dict의 길이는 132690입니다.
# 407000번째 문서 처리 중이며 word_to_idx_dict의 길이는 132837입니다.
# 408000번째 문서 처리 중이며 word_to_idx_dict의 길이는 133009입니다.
# 409000번째 문서 처리 중이며 word_to_idx_dict의 길이는 133156입니다.
# 410000번째 문서 처리 중이며 word_to_idx_dict의 길이는 133299입니다.
# 411000번째 문서 처리 중이며 word_to_idx_dict의 길이는 133469입니다.
# 412000번째 문서 처리 중이며 word_to_idx_dict의 길이는 133655입니다.
# 413000번째 문서 처리 중이며 word_to_idx_dict의 길이는 133815입니다.
# 414000번째 문서 처리 중이며 word_to_idx_dict의 길이는 134018입니다.
# 415000번째 문서 처리 중이며 word_to_idx_dict의 길이는 134195입니다.
# 416000번째 문서 처리 중이며 word_to_idx_dict의 길이는 134376입니다.
# 417000번째 문서 처리 중이며 word_to_idx_dict의 길이는 134531입니다.
# 418000번째 문서 처리 중이며 word_to_idx_dict의 길이는 134699입니다.
# 419000번째 문서 처리 중이며 word_to_idx_dict의 길이는 134846입니다.
# 420000번째 문서 처리 중이며 word_to_idx_dict의 길이는 134984입니다.
# 421000번째 문서 처리 중이며 word_to_idx_dict의 길이는 135143입니다.
# 422000번째 문서 처리 중이며 word_to_idx_dict의 길이는 135285입니다.
# 423000번째 문서 처리 중이며 word_to_idx_dict의 길이는 135456입니다.
# 424000번째 문서 처리 중이며 word_to_idx_dict의 길이는 135625입니다.
# 425000번째 문서 처리 중이며 word_to_idx_dict의 길이는 135764입니다.
# 426000번째 문서 처리 중이며 word_to_idx_dict의 길이는 135938입니다.
# 427000번째 문서 처리 중이며 word_to_idx_dict의 길이는 136081입니다.
# 428000번째 문서 처리 중이며 word_to_idx_dict의 길이는 136226입니다.
# 429000번째 문서 처리 중이며 word_to_idx_dict의 길이는 136375입니다.
# 430000번째 문서 처리 중이며 word_to_idx_dict의 길이는 136530입니다.
# 431000번째 문서 처리 중이며 word_to_idx_dict의 길이는 136682입니다.
# 432000번째 문서 처리 중이며 word_to_idx_dict의 길이는 136810입니다.
# 433000번째 문서 처리 중이며 word_to_idx_dict의 길이는 136987입니다.
# 434000번째 문서 처리 중이며 word_to_idx_dict의 길이는 137131입니다.
# 435000번째 문서 처리 중이며 word_to_idx_dict의 길이는 137273입니다.
# 436000번째 문서 처리 중이며 word_to_idx_dict의 길이는 137417입니다.
# 437000번째 문서 처리 중이며 word_to_idx_dict의 길이는 137598입니다.
# 438000번째 문서 처리 중이며 word_to_idx_dict의 길이는 137750입니다.
# 439000번째 문서 처리 중이며 word_to_idx_dict의 길이는 137904입니다.
# 440000번째 문서 처리 중이며 word_to_idx_dict의 길이는 138068입니다.
# 441000번째 문서 처리 중이며 word_to_idx_dict의 길이는 138221입니다.
# 442000번째 문서 처리 중이며 word_to_idx_dict의 길이는 138378입니다.
# 443000번째 문서 처리 중이며 word_to_idx_dict의 길이는 138556입니다.
# 444000번째 문서 처리 중이며 word_to_idx_dict의 길이는 138710입니다.
# 445000번째 문서 처리 중이며 word_to_idx_dict의 길이는 138832입니다.
# 446000번째 문서 처리 중이며 word_to_idx_dict의 길이는 138980입니다.
# 447000번째 문서 처리 중이며 word_to_idx_dict의 길이는 139110입니다.
# 448000번째 문서 처리 중이며 word_to_idx_dict의 길이는 139230입니다.
# 449000번째 문서 처리 중이며 word_to_idx_dict의 길이는 139354입니다.
# 450000번째 문서 처리 중이며 word_to_idx_dict의 길이는 139521입니다.
# 451000번째 문서 처리 중이며 word_to_idx_dict의 길이는 139664입니다.
# 452000번째 문서 처리 중이며 word_to_idx_dict의 길이는 139847입니다.
# 453000번째 문서 처리 중이며 word_to_idx_dict의 길이는 140001입니다.
# 454000번째 문서 처리 중이며 word_to_idx_dict의 길이는 140159입니다.
# 455000번째 문서 처리 중이며 word_to_idx_dict의 길이는 140293입니다.
# 456000번째 문서 처리 중이며 word_to_idx_dict의 길이는 140418입니다.
# 457000번째 문서 처리 중이며 word_to_idx_dict의 길이는 140592입니다.
# 458000번째 문서 처리 중이며 word_to_idx_dict의 길이는 140765입니다.
# 459000번째 문서 처리 중이며 word_to_idx_dict의 길이는 140934입니다.
# 460000번째 문서 처리 중이며 word_to_idx_dict의 길이는 141084입니다.
# 461000번째 문서 처리 중이며 word_to_idx_dict의 길이는 141260입니다.
# 462000번째 문서 처리 중이며 word_to_idx_dict의 길이는 141427입니다.
# 463000번째 문서 처리 중이며 word_to_idx_dict의 길이는 141562입니다.
# 464000번째 문서 처리 중이며 word_to_idx_dict의 길이는 141712입니다.
# 465000번째 문서 처리 중이며 word_to_idx_dict의 길이는 141898입니다.
# 466000번째 문서 처리 중이며 word_to_idx_dict의 길이는 142027입니다.
# 467000번째 문서 처리 중이며 word_to_idx_dict의 길이는 142182입니다.
# 468000번째 문서 처리 중이며 word_to_idx_dict의 길이는 142335입니다.
# 469000번째 문서 처리 중이며 word_to_idx_dict의 길이는 142619입니다.
# 470000번째 문서 처리 중이며 word_to_idx_dict의 길이는 142754입니다.
# 471000번째 문서 처리 중이며 word_to_idx_dict의 길이는 142905입니다.
# 472000번째 문서 처리 중이며 word_to_idx_dict의 길이는 143050입니다.
# 473000번째 문서 처리 중이며 word_to_idx_dict의 길이는 143199입니다.
# 474000번째 문서 처리 중이며 word_to_idx_dict의 길이는 143323입니다.
# 475000번째 문서 처리 중이며 word_to_idx_dict의 길이는 143471입니다.
# 476000번째 문서 처리 중이며 word_to_idx_dict의 길이는 143612입니다.
# 477000번째 문서 처리 중이며 word_to_idx_dict의 길이는 143750입니다.
# 478000번째 문서 처리 중이며 word_to_idx_dict의 길이는 143910입니다.
# 479000번째 문서 처리 중이며 word_to_idx_dict의 길이는 144067입니다.
# 480000번째 문서 처리 중이며 word_to_idx_dict의 길이는 144232입니다.
# 481000번째 문서 처리 중이며 word_to_idx_dict의 길이는 144370입니다.
# 482000번째 문서 처리 중이며 word_to_idx_dict의 길이는 144506입니다.
# 483000번째 문서 처리 중이며 word_to_idx_dict의 길이는 144666입니다.
# 484000번째 문서 처리 중이며 word_to_idx_dict의 길이는 144816입니다.
# 485000번째 문서 처리 중이며 word_to_idx_dict의 길이는 144971입니다.
# 486000번째 문서 처리 중이며 word_to_idx_dict의 길이는 145147입니다.
# 487000번째 문서 처리 중이며 word_to_idx_dict의 길이는 145297입니다.
# 488000번째 문서 처리 중이며 word_to_idx_dict의 길이는 145471입니다.
# 489000번째 문서 처리 중이며 word_to_idx_dict의 길이는 145598입니다.
# 490000번째 문서 처리 중이며 word_to_idx_dict의 길이는 145764입니다.
# 491000번째 문서 처리 중이며 word_to_idx_dict의 길이는 145885입니다.
# 492000번째 문서 처리 중이며 word_to_idx_dict의 길이는 146039입니다.
# 493000번째 문서 처리 중이며 word_to_idx_dict의 길이는 146217입니다.
# 494000번째 문서 처리 중이며 word_to_idx_dict의 길이는 146362입니다.
# 495000번째 문서 처리 중이며 word_to_idx_dict의 길이는 146528입니다.
# 496000번째 문서 처리 중이며 word_to_idx_dict의 길이는 146692입니다.
# 497000번째 문서 처리 중이며 word_to_idx_dict의 길이는 146827입니다.
# 498000번째 문서 처리 중이며 word_to_idx_dict의 길이는 146939입니다.
# 499000번째 문서 처리 중이며 word_to_idx_dict의 길이는 147128입니다.
# 500000번째 문서 처리 중이며 word_to_idx_dict의 길이는 147228입니다.
# 501000번째 문서 처리 중이며 word_to_idx_dict의 길이는 147360입니다.
# 502000번째 문서 처리 중이며 word_to_idx_dict의 길이는 147532입니다.
# 503000번째 문서 처리 중이며 word_to_idx_dict의 길이는 147650입니다.
# 504000번째 문서 처리 중이며 word_to_idx_dict의 길이는 147860입니다.
# 505000번째 문서 처리 중이며 word_to_idx_dict의 길이는 147995입니다.
# 506000번째 문서 처리 중이며 word_to_idx_dict의 길이는 148153입니다.
# 507000번째 문서 처리 중이며 word_to_idx_dict의 길이는 148293입니다.
# 508000번째 문서 처리 중이며 word_to_idx_dict의 길이는 148416입니다.
# 509000번째 문서 처리 중이며 word_to_idx_dict의 길이는 148547입니다.
# 510000번째 문서 처리 중이며 word_to_idx_dict의 길이는 148733입니다.
# 511000번째 문서 처리 중이며 word_to_idx_dict의 길이는 148879입니다.
# 512000번째 문서 처리 중이며 word_to_idx_dict의 길이는 149025입니다.
# 513000번째 문서 처리 중이며 word_to_idx_dict의 길이는 149149입니다.
# 514000번째 문서 처리 중이며 word_to_idx_dict의 길이는 149279입니다.
# 515000번째 문서 처리 중이며 word_to_idx_dict의 길이는 149391입니다.
# 516000번째 문서 처리 중이며 word_to_idx_dict의 길이는 149550입니다.
# 517000번째 문서 처리 중이며 word_to_idx_dict의 길이는 149695입니다.
# 518000번째 문서 처리 중이며 word_to_idx_dict의 길이는 149855입니다.
# 519000번째 문서 처리 중이며 word_to_idx_dict의 길이는 149994입니다.
# 520000번째 문서 처리 중이며 word_to_idx_dict의 길이는 150131입니다.
# 521000번째 문서 처리 중이며 word_to_idx_dict의 길이는 150269입니다.
# 522000번째 문서 처리 중이며 word_to_idx_dict의 길이는 150440입니다.
# 523000번째 문서 처리 중이며 word_to_idx_dict의 길이는 150565입니다.
# 524000번째 문서 처리 중이며 word_to_idx_dict의 길이는 150741입니다.
# 525000번째 문서 처리 중이며 word_to_idx_dict의 길이는 150869입니다.
# 526000번째 문서 처리 중이며 word_to_idx_dict의 길이는 151015입니다.
# 527000번째 문서 처리 중이며 word_to_idx_dict의 길이는 151153입니다.
# 528000번째 문서 처리 중이며 word_to_idx_dict의 길이는 151277입니다.
# 529000번째 문서 처리 중이며 word_to_idx_dict의 길이는 151413입니다.
# 530000번째 문서 처리 중이며 word_to_idx_dict의 길이는 151565입니다.
# 531000번째 문서 처리 중이며 word_to_idx_dict의 길이는 151717입니다.
# 532000번째 문서 처리 중이며 word_to_idx_dict의 길이는 151863입니다.
# 533000번째 문서 처리 중이며 word_to_idx_dict의 길이는 151999입니다.
# 534000번째 문서 처리 중이며 word_to_idx_dict의 길이는 152126입니다.
# 535000번째 문서 처리 중이며 word_to_idx_dict의 길이는 152248입니다.
# 536000번째 문서 처리 중이며 word_to_idx_dict의 길이는 152387입니다.
# 537000번째 문서 처리 중이며 word_to_idx_dict의 길이는 152511입니다.
# 538000번째 문서 처리 중이며 word_to_idx_dict의 길이는 152638입니다.
# 539000번째 문서 처리 중이며 word_to_idx_dict의 길이는 152773입니다.
# 540000번째 문서 처리 중이며 word_to_idx_dict의 길이는 152896입니다.
# 541000번째 문서 처리 중이며 word_to_idx_dict의 길이는 153054입니다.
# 542000번째 문서 처리 중이며 word_to_idx_dict의 길이는 153233입니다.
# 543000번째 문서 처리 중이며 word_to_idx_dict의 길이는 153366입니다.
# 544000번째 문서 처리 중이며 word_to_idx_dict의 길이는 153502입니다.
# 545000번째 문서 처리 중이며 word_to_idx_dict의 길이는 153625입니다.
# 546000번째 문서 처리 중이며 word_to_idx_dict의 길이는 153754입니다.
# 547000번째 문서 처리 중이며 word_to_idx_dict의 길이는 153898입니다.
# 548000번째 문서 처리 중이며 word_to_idx_dict의 길이는 154036입니다.
# 549000번째 문서 처리 중이며 word_to_idx_dict의 길이는 154158입니다.
# 550000번째 문서 처리 중이며 word_to_idx_dict의 길이는 154305입니다.
# 551000번째 문서 처리 중이며 word_to_idx_dict의 길이는 154412입니다.
# 552000번째 문서 처리 중이며 word_to_idx_dict의 길이는 154545입니다.
# 553000번째 문서 처리 중이며 word_to_idx_dict의 길이는 154709입니다.
# 554000번째 문서 처리 중이며 word_to_idx_dict의 길이는 154836입니다.
# 555000번째 문서 처리 중이며 word_to_idx_dict의 길이는 154988입니다.
# 556000번째 문서 처리 중이며 word_to_idx_dict의 길이는 155138입니다.
# 557000번째 문서 처리 중이며 word_to_idx_dict의 길이는 155270입니다.
# 558000번째 문서 처리 중이며 word_to_idx_dict의 길이는 155411입니다.
# 559000번째 문서 처리 중이며 word_to_idx_dict의 길이는 155586입니다.
# 560000번째 문서 처리 중이며 word_to_idx_dict의 길이는 155736입니다.
# 561000번째 문서 처리 중이며 word_to_idx_dict의 길이는 155865입니다.
# 562000번째 문서 처리 중이며 word_to_idx_dict의 길이는 156010입니다.
# 563000번째 문서 처리 중이며 word_to_idx_dict의 길이는 156140입니다.
# 564000번째 문서 처리 중이며 word_to_idx_dict의 길이는 156290입니다.
# 565000번째 문서 처리 중이며 word_to_idx_dict의 길이는 156448입니다.
# 566000번째 문서 처리 중이며 word_to_idx_dict의 길이는 156592입니다.
# 567000번째 문서 처리 중이며 word_to_idx_dict의 길이는 156691입니다.
# 568000번째 문서 처리 중이며 word_to_idx_dict의 길이는 156838입니다.
# 569000번째 문서 처리 중이며 word_to_idx_dict의 길이는 156959입니다.
# 570000번째 문서 처리 중이며 word_to_idx_dict의 길이는 157082입니다.
# 571000번째 문서 처리 중이며 word_to_idx_dict의 길이는 157220입니다.
# 572000번째 문서 처리 중이며 word_to_idx_dict의 길이는 157328입니다.
# 573000번째 문서 처리 중이며 word_to_idx_dict의 길이는 157470입니다.
# 574000번째 문서 처리 중이며 word_to_idx_dict의 길이는 157601입니다.
# 575000번째 문서 처리 중이며 word_to_idx_dict의 길이는 157705입니다.
# 576000번째 문서 처리 중이며 word_to_idx_dict의 길이는 157830입니다.
# 577000번째 문서 처리 중이며 word_to_idx_dict의 길이는 157968입니다.
# 578000번째 문서 처리 중이며 word_to_idx_dict의 길이는 158096입니다.
# 579000번째 문서 처리 중이며 word_to_idx_dict의 길이는 158244입니다.
# 580000번째 문서 처리 중이며 word_to_idx_dict의 길이는 158372입니다.
# 581000번째 문서 처리 중이며 word_to_idx_dict의 길이는 158489입니다.
# 582000번째 문서 처리 중이며 word_to_idx_dict의 길이는 158614입니다.
# 583000번째 문서 처리 중이며 word_to_idx_dict의 길이는 158723입니다.
# 584000번째 문서 처리 중이며 word_to_idx_dict의 길이는 158876입니다.
# 585000번째 문서 처리 중이며 word_to_idx_dict의 길이는 159003입니다.
# 586000번째 문서 처리 중이며 word_to_idx_dict의 길이는 159136입니다.
# 587000번째 문서 처리 중이며 word_to_idx_dict의 길이는 159269입니다.
# 588000번째 문서 처리 중이며 word_to_idx_dict의 길이는 159388입니다.
# 589000번째 문서 처리 중이며 word_to_idx_dict의 길이는 159516입니다.
# 590000번째 문서 처리 중이며 word_to_idx_dict의 길이는 159641입니다.
# 591000번째 문서 처리 중이며 word_to_idx_dict의 길이는 159780입니다.
# 592000번째 문서 처리 중이며 word_to_idx_dict의 길이는 159947입니다.
# 593000번째 문서 처리 중이며 word_to_idx_dict의 길이는 160083입니다.
# 594000번째 문서 처리 중이며 word_to_idx_dict의 길이는 160201입니다.
# 595000번째 문서 처리 중이며 word_to_idx_dict의 길이는 160338입니다.
# 596000번째 문서 처리 중이며 word_to_idx_dict의 길이는 160468입니다.
# 597000번째 문서 처리 중이며 word_to_idx_dict의 길이는 160599입니다.
# 598000번째 문서 처리 중이며 word_to_idx_dict의 길이는 160740입니다.
# 599000번째 문서 처리 중이며 word_to_idx_dict의 길이는 160869입니다.
# 600000번째 문서 처리 중이며 word_to_idx_dict의 길이는 161012입니다.
# 601000번째 문서 처리 중이며 word_to_idx_dict의 길이는 161123입니다.
# 602000번째 문서 처리 중이며 word_to_idx_dict의 길이는 161265입니다.
# 603000번째 문서 처리 중이며 word_to_idx_dict의 길이는 161416입니다.
# 604000번째 문서 처리 중이며 word_to_idx_dict의 길이는 161575입니다.
# 605000번째 문서 처리 중이며 word_to_idx_dict의 길이는 161685입니다.
# 606000번째 문서 처리 중이며 word_to_idx_dict의 길이는 161830입니다.
# 607000번째 문서 처리 중이며 word_to_idx_dict의 길이는 161971입니다.
# 608000번째 문서 처리 중이며 word_to_idx_dict의 길이는 162119입니다.
# 609000번째 문서 처리 중이며 word_to_idx_dict의 길이는 162240입니다.
# 610000번째 문서 처리 중이며 word_to_idx_dict의 길이는 162380입니다.
# 611000번째 문서 처리 중이며 word_to_idx_dict의 길이는 162503입니다.
# 612000번째 문서 처리 중이며 word_to_idx_dict의 길이는 162630입니다.
# 613000번째 문서 처리 중이며 word_to_idx_dict의 길이는 162766입니다.
# 614000번째 문서 처리 중이며 word_to_idx_dict의 길이는 162888입니다.
# 615000번째 문서 처리 중이며 word_to_idx_dict의 길이는 163016입니다.
# 616000번째 문서 처리 중이며 word_to_idx_dict의 길이는 163113입니다.
# 617000번째 문서 처리 중이며 word_to_idx_dict의 길이는 163246입니다.
# 618000번째 문서 처리 중이며 word_to_idx_dict의 길이는 163396입니다.
# 619000번째 문서 처리 중이며 word_to_idx_dict의 길이는 163501입니다.
# 620000번째 문서 처리 중이며 word_to_idx_dict의 길이는 163646입니다.
# 621000번째 문서 처리 중이며 word_to_idx_dict의 길이는 163761입니다.
# 622000번째 문서 처리 중이며 word_to_idx_dict의 길이는 163887입니다.
# 623000번째 문서 처리 중이며 word_to_idx_dict의 길이는 164021입니다.
# 624000번째 문서 처리 중이며 word_to_idx_dict의 길이는 164134입니다.
# 625000번째 문서 처리 중이며 word_to_idx_dict의 길이는 164262입니다.
# 626000번째 문서 처리 중이며 word_to_idx_dict의 길이는 164386입니다.
# 627000번째 문서 처리 중이며 word_to_idx_dict의 길이는 164547입니다.
# 628000번째 문서 처리 중이며 word_to_idx_dict의 길이는 164659입니다.
# 629000번째 문서 처리 중이며 word_to_idx_dict의 길이는 164779입니다.
# 630000번째 문서 처리 중이며 word_to_idx_dict의 길이는 164900입니다.
# 631000번째 문서 처리 중이며 word_to_idx_dict의 길이는 165023입니다.
# 632000번째 문서 처리 중이며 word_to_idx_dict의 길이는 165170입니다.
# 633000번째 문서 처리 중이며 word_to_idx_dict의 길이는 165317입니다.
# 634000번째 문서 처리 중이며 word_to_idx_dict의 길이는 165469입니다.
# 635000번째 문서 처리 중이며 word_to_idx_dict의 길이는 165619입니다.
# 636000번째 문서 처리 중이며 word_to_idx_dict의 길이는 165762입니다.
# 637000번째 문서 처리 중이며 word_to_idx_dict의 길이는 165906입니다.
# 638000번째 문서 처리 중이며 word_to_idx_dict의 길이는 166030입니다.
# 639000번째 문서 처리 중이며 word_to_idx_dict의 길이는 166153입니다.
# 640000번째 문서 처리 중이며 word_to_idx_dict의 길이는 166287입니다.
# 641000번째 문서 처리 중이며 word_to_idx_dict의 길이는 166427입니다.
# 642000번째 문서 처리 중이며 word_to_idx_dict의 길이는 166576입니다.
# 643000번째 문서 처리 중이며 word_to_idx_dict의 길이는 166719입니다.
# 644000번째 문서 처리 중이며 word_to_idx_dict의 길이는 166843입니다.
# 645000번째 문서 처리 중이며 word_to_idx_dict의 길이는 166971입니다.
# 646000번째 문서 처리 중이며 word_to_idx_dict의 길이는 167119입니다.
# 647000번째 문서 처리 중이며 word_to_idx_dict의 길이는 167250입니다.
# 648000번째 문서 처리 중이며 word_to_idx_dict의 길이는 167362입니다.
# 649000번째 문서 처리 중이며 word_to_idx_dict의 길이는 167472입니다.
# 650000번째 문서 처리 중이며 word_to_idx_dict의 길이는 167589입니다.
# 651000번째 문서 처리 중이며 word_to_idx_dict의 길이는 167724입니다.
# 652000번째 문서 처리 중이며 word_to_idx_dict의 길이는 167844입니다.
# 653000번째 문서 처리 중이며 word_to_idx_dict의 길이는 167977입니다.
# 654000번째 문서 처리 중이며 word_to_idx_dict의 길이는 168095입니다.
# 655000번째 문서 처리 중이며 word_to_idx_dict의 길이는 168220입니다.
# 656000번째 문서 처리 중이며 word_to_idx_dict의 길이는 168350입니다.
# 657000번째 문서 처리 중이며 word_to_idx_dict의 길이는 168445입니다.
# 658000번째 문서 처리 중이며 word_to_idx_dict의 길이는 168567입니다.
# 659000번째 문서 처리 중이며 word_to_idx_dict의 길이는 168680입니다.
# 660000번째 문서 처리 중이며 word_to_idx_dict의 길이는 168810입니다.
# 661000번째 문서 처리 중이며 word_to_idx_dict의 길이는 168917입니다.
# 662000번째 문서 처리 중이며 word_to_idx_dict의 길이는 169052입니다.
# 663000번째 문서 처리 중이며 word_to_idx_dict의 길이는 169156입니다.
# 664000번째 문서 처리 중이며 word_to_idx_dict의 길이는 169293입니다.
# 665000번째 문서 처리 중이며 word_to_idx_dict의 길이는 169396입니다.
# 666000번째 문서 처리 중이며 word_to_idx_dict의 길이는 169526입니다.
# 667000번째 문서 처리 중이며 word_to_idx_dict의 길이는 169638입니다.
# 668000번째 문서 처리 중이며 word_to_idx_dict의 길이는 169773입니다.
# 669000번째 문서 처리 중이며 word_to_idx_dict의 길이는 169877입니다.

# %%
word_to_freq_dict = defaultdict(int)

for idx,doc in enumerate(x_train) : 
    if idx % 1000 == 0 : print("{}번째 문서 처리 중이며 word_to_freq_dict의 길이는 {}입니다."\
                               .format(idx,len(word_to_freq_dict)))
    for sent in doc[0] : 
        for word in sent : 
            word_to_freq_dict[word] += 1
# Out:
# 0번째 문서 처리 중이며 word_to_freq_dict의 길이는 0입니다.
# 1000번째 문서 처리 중이며 word_to_freq_dict의 길이는 6809입니다.
# 2000번째 문서 처리 중이며 word_to_freq_dict의 길이는 9734입니다.
# 3000번째 문서 처리 중이며 word_to_freq_dict의 길이는 12152입니다.
# 4000번째 문서 처리 중이며 word_to_freq_dict의 길이는 13988입니다.
# 5000번째 문서 처리 중이며 word_to_freq_dict의 길이는 15808입니다.
# 6000번째 문서 처리 중이며 word_to_freq_dict의 길이는 17214입니다.
# 7000번째 문서 처리 중이며 word_to_freq_dict의 길이는 18830입니다.
# 8000번째 문서 처리 중이며 word_to_freq_dict의 길이는 20069입니다.
# 9000번째 문서 처리 중이며 word_to_freq_dict의 길이는 21229입니다.
# 10000번째 문서 처리 중이며 word_to_freq_dict의 길이는 22392입니다.
# 11000번째 문서 처리 중이며 word_to_freq_dict의 길이는 23515입니다.
# 12000번째 문서 처리 중이며 word_to_freq_dict의 길이는 24555입니다.
# 13000번째 문서 처리 중이며 word_to_freq_dict의 길이는 25639입니다.
# 14000번째 문서 처리 중이며 word_to_freq_dict의 길이는 26565입니다.
# 15000번째 문서 처리 중이며 word_to_freq_dict의 길이는 27405입니다.
# 16000번째 문서 처리 중이며 word_to_freq_dict의 길이는 28206입니다.
# 17000번째 문서 처리 중이며 word_to_freq_dict의 길이는 29154입니다.
# 18000번째 문서 처리 중이며 word_to_freq_dict의 길이는 29874입니다.
# 19000번째 문서 처리 중이며 word_to_freq_dict의 길이는 30663입니다.
# 20000번째 문서 처리 중이며 word_to_freq_dict의 길이는 31313입니다.
# 21000번째 문서 처리 중이며 word_to_freq_dict의 길이는 32148입니다.
# 22000번째 문서 처리 중이며 word_to_freq_dict의 길이는 32912입니다.
# 23000번째 문서 처리 중이며 word_to_freq_dict의 길이는 33613입니다.
# 24000번째 문서 처리 중이며 word_to_freq_dict의 길이는 34342입니다.
# 25000번째 문서 처리 중이며 word_to_freq_dict의 길이는 35011입니다.
# 26000번째 문서 처리 중이며 word_to_freq_dict의 길이는 35602입니다.
# 27000번째 문서 처리 중이며 word_to_freq_dict의 길이는 36182입니다.
# 28000번째 문서 처리 중이며 word_to_freq_dict의 길이는 36824입니다.
# 29000번째 문서 처리 중이며 word_to_freq_dict의 길이는 37538입니다.
# 30000번째 문서 처리 중이며 word_to_freq_dict의 길이는 38155입니다.
# 31000번째 문서 처리 중이며 word_to_freq_dict의 길이는 38668입니다.
# 32000번째 문서 처리 중이며 word_to_freq_dict의 길이는 39264입니다.
# 33000번째 문서 처리 중이며 word_to_freq_dict의 길이는 39820입니다.
# 34000번째 문서 처리 중이며 word_to_freq_dict의 길이는 40387입니다.
# 35000번째 문서 처리 중이며 word_to_freq_dict의 길이는 40956입니다.
# 36000번째 문서 처리 중이며 word_to_freq_dict의 길이는 41500입니다.
# 37000번째 문서 처리 중이며 word_to_freq_dict의 길이는 42053입니다.
# 38000번째 문서 처리 중이며 word_to_freq_dict의 길이는 42659입니다.
# 39000번째 문서 처리 중이며 word_to_freq_dict의 길이는 43208입니다.
# 40000번째 문서 처리 중이며 word_to_freq_dict의 길이는 43696입니다.
# 41000번째 문서 처리 중이며 word_to_freq_dict의 길이는 44215입니다.
# 42000번째 문서 처리 중이며 word_to_freq_dict의 길이는 44689입니다.
# 43000번째 문서 처리 중이며 word_to_freq_dict의 길이는 45209입니다.
# 44000번째 문서 처리 중이며 word_to_freq_dict의 길이는 45682입니다.
# 45000번째 문서 처리 중이며 word_to_freq_dict의 길이는 46138입니다.
# 46000번째 문서 처리 중이며 word_to_freq_dict의 길이는 46641입니다.
# 47000번째 문서 처리 중이며 word_to_freq_dict의 길이는 47184입니다.
# 48000번째 문서 처리 중이며 word_to_freq_dict의 길이는 47720입니다.
# 49000번째 문서 처리 중이며 word_to_freq_dict의 길이는 48217입니다.
# 50000번째 문서 처리 중이며 word_to_freq_dict의 길이는 48706입니다.
# 51000번째 문서 처리 중이며 word_to_freq_dict의 길이는 49167입니다.
# 52000번째 문서 처리 중이며 word_to_freq_dict의 길이는 49594입니다.
# 53000번째 문서 처리 중이며 word_to_freq_dict의 길이는 50091입니다.
# 54000번째 문서 처리 중이며 word_to_freq_dict의 길이는 50523입니다.
# 55000번째 문서 처리 중이며 word_to_freq_dict의 길이는 50958입니다.
# 56000번째 문서 처리 중이며 word_to_freq_dict의 길이는 51373입니다.
# 57000번째 문서 처리 중이며 word_to_freq_dict의 길이는 51773입니다.
# 58000번째 문서 처리 중이며 word_to_freq_dict의 길이는 52153입니다.
# 59000번째 문서 처리 중이며 word_to_freq_dict의 길이는 52575입니다.
# 60000번째 문서 처리 중이며 word_to_freq_dict의 길이는 52947입니다.
# 61000번째 문서 처리 중이며 word_to_freq_dict의 길이는 53355입니다.
# 62000번째 문서 처리 중이며 word_to_freq_dict의 길이는 53747입니다.
# 63000번째 문서 처리 중이며 word_to_freq_dict의 길이는 54127입니다.
# 64000번째 문서 처리 중이며 word_to_freq_dict의 길이는 54560입니다.
# 65000번째 문서 처리 중이며 word_to_freq_dict의 길이는 54950입니다.
# 66000번째 문서 처리 중이며 word_to_freq_dict의 길이는 55348입니다.
# 67000번째 문서 처리 중이며 word_to_freq_dict의 길이는 55736입니다.
# 68000번째 문서 처리 중이며 word_to_freq_dict의 길이는 56093입니다.
# 69000번째 문서 처리 중이며 word_to_freq_dict의 길이는 56510입니다.
# 70000번째 문서 처리 중이며 word_to_freq_dict의 길이는 56894입니다.
# 71000번째 문서 처리 중이며 word_to_freq_dict의 길이는 57272입니다.
# 72000번째 문서 처리 중이며 word_to_freq_dict의 길이는 57638입니다.
# 73000번째 문서 처리 중이며 word_to_freq_dict의 길이는 57998입니다.
# 74000번째 문서 처리 중이며 word_to_freq_dict의 길이는 58313입니다.
# 75000번째 문서 처리 중이며 word_to_freq_dict의 길이는 58678입니다.
# 76000번째 문서 처리 중이며 word_to_freq_dict의 길이는 59078입니다.
# 77000번째 문서 처리 중이며 word_to_freq_dict의 길이는 59452입니다.
# 78000번째 문서 처리 중이며 word_to_freq_dict의 길이는 59834입니다.
# 79000번째 문서 처리 중이며 word_to_freq_dict의 길이는 60191입니다.
# 80000번째 문서 처리 중이며 word_to_freq_dict의 길이는 60516입니다.
# 81000번째 문서 처리 중이며 word_to_freq_dict의 길이는 60862입니다.
# 82000번째 문서 처리 중이며 word_to_freq_dict의 길이는 61257입니다.
# 83000번째 문서 처리 중이며 word_to_freq_dict의 길이는 61679입니다.
# 84000번째 문서 처리 중이며 word_to_freq_dict의 길이는 62071입니다.
# 85000번째 문서 처리 중이며 word_to_freq_dict의 길이는 62422입니다.
# 86000번째 문서 처리 중이며 word_to_freq_dict의 길이는 62782입니다.
# 87000번째 문서 처리 중이며 word_to_freq_dict의 길이는 63095입니다.
# 88000번째 문서 처리 중이며 word_to_freq_dict의 길이는 63454입니다.
# 89000번째 문서 처리 중이며 word_to_freq_dict의 길이는 63822입니다.
# 90000번째 문서 처리 중이며 word_to_freq_dict의 길이는 64143입니다.
# 91000번째 문서 처리 중이며 word_to_freq_dict의 길이는 64473입니다.
# 92000번째 문서 처리 중이며 word_to_freq_dict의 길이는 64830입니다.
# 93000번째 문서 처리 중이며 word_to_freq_dict의 길이는 65128입니다.
# 94000번째 문서 처리 중이며 word_to_freq_dict의 길이는 65444입니다.
# 95000번째 문서 처리 중이며 word_to_freq_dict의 길이는 65845입니다.
# 96000번째 문서 처리 중이며 word_to_freq_dict의 길이는 66187입니다.
# 97000번째 문서 처리 중이며 word_to_freq_dict의 길이는 66499입니다.
# 98000번째 문서 처리 중이며 word_to_freq_dict의 길이는 66829입니다.
# 99000번째 문서 처리 중이며 word_to_freq_dict의 길이는 67152입니다.
# 100000번째 문서 처리 중이며 word_to_freq_dict의 길이는 67489입니다.
# 101000번째 문서 처리 중이며 word_to_freq_dict의 길이는 67818입니다.
# 102000번째 문서 처리 중이며 word_to_freq_dict의 길이는 68188입니다.
# 103000번째 문서 처리 중이며 word_to_freq_dict의 길이는 68468입니다.
# 104000번째 문서 처리 중이며 word_to_freq_dict의 길이는 68785입니다.
# 105000번째 문서 처리 중이며 word_to_freq_dict의 길이는 69065입니다.
# 106000번째 문서 처리 중이며 word_to_freq_dict의 길이는 69356입니다.
# 107000번째 문서 처리 중이며 word_to_freq_dict의 길이는 69722입니다.
# 108000번째 문서 처리 중이며 word_to_freq_dict의 길이는 70011입니다.
# 109000번째 문서 처리 중이며 word_to_freq_dict의 길이는 70287입니다.
# 110000번째 문서 처리 중이며 word_to_freq_dict의 길이는 70584입니다.
# 111000번째 문서 처리 중이며 word_to_freq_dict의 길이는 70881입니다.
# 112000번째 문서 처리 중이며 word_to_freq_dict의 길이는 71178입니다.
# 113000번째 문서 처리 중이며 word_to_freq_dict의 길이는 71515입니다.
# 114000번째 문서 처리 중이며 word_to_freq_dict의 길이는 71828입니다.
# 115000번째 문서 처리 중이며 word_to_freq_dict의 길이는 72143입니다.
# 116000번째 문서 처리 중이며 word_to_freq_dict의 길이는 72388입니다.
# 117000번째 문서 처리 중이며 word_to_freq_dict의 길이는 72720입니다.
# 118000번째 문서 처리 중이며 word_to_freq_dict의 길이는 73015입니다.
# 119000번째 문서 처리 중이며 word_to_freq_dict의 길이는 73295입니다.
# 120000번째 문서 처리 중이며 word_to_freq_dict의 길이는 73624입니다.
# 121000번째 문서 처리 중이며 word_to_freq_dict의 길이는 73929입니다.
# 122000번째 문서 처리 중이며 word_to_freq_dict의 길이는 74208입니다.
# 123000번째 문서 처리 중이며 word_to_freq_dict의 길이는 74542입니다.
# 124000번째 문서 처리 중이며 word_to_freq_dict의 길이는 74827입니다.
# 125000번째 문서 처리 중이며 word_to_freq_dict의 길이는 75135입니다.
# 126000번째 문서 처리 중이며 word_to_freq_dict의 길이는 75421입니다.
# 127000번째 문서 처리 중이며 word_to_freq_dict의 길이는 75650입니다.
# 128000번째 문서 처리 중이며 word_to_freq_dict의 길이는 75930입니다.
# 129000번째 문서 처리 중이며 word_to_freq_dict의 길이는 76231입니다.
# 130000번째 문서 처리 중이며 word_to_freq_dict의 길이는 76503입니다.
# 131000번째 문서 처리 중이며 word_to_freq_dict의 길이는 76789입니다.
# 132000번째 문서 처리 중이며 word_to_freq_dict의 길이는 77076입니다.
# 133000번째 문서 처리 중이며 word_to_freq_dict의 길이는 77362입니다.
# 134000번째 문서 처리 중이며 word_to_freq_dict의 길이는 77627입니다.
# 135000번째 문서 처리 중이며 word_to_freq_dict의 길이는 77907입니다.
# 136000번째 문서 처리 중이며 word_to_freq_dict의 길이는 78178입니다.
# 137000번째 문서 처리 중이며 word_to_freq_dict의 길이는 78477입니다.
# 138000번째 문서 처리 중이며 word_to_freq_dict의 길이는 78766입니다.
# 139000번째 문서 처리 중이며 word_to_freq_dict의 길이는 79069입니다.
# 140000번째 문서 처리 중이며 word_to_freq_dict의 길이는 79356입니다.
# 141000번째 문서 처리 중이며 word_to_freq_dict의 길이는 79595입니다.
# 142000번째 문서 처리 중이며 word_to_freq_dict의 길이는 79844입니다.
# 143000번째 문서 처리 중이며 word_to_freq_dict의 길이는 80144입니다.
# 144000번째 문서 처리 중이며 word_to_freq_dict의 길이는 80423입니다.
# 145000번째 문서 처리 중이며 word_to_freq_dict의 길이는 80713입니다.
# 146000번째 문서 처리 중이며 word_to_freq_dict의 길이는 80995입니다.
# 147000번째 문서 처리 중이며 word_to_freq_dict의 길이는 81337입니다.
# 148000번째 문서 처리 중이며 word_to_freq_dict의 길이는 81605입니다.
# 149000번째 문서 처리 중이며 word_to_freq_dict의 길이는 81890입니다.
# 150000번째 문서 처리 중이며 word_to_freq_dict의 길이는 82173입니다.
# 151000번째 문서 처리 중이며 word_to_freq_dict의 길이는 82412입니다.
# 152000번째 문서 처리 중이며 word_to_freq_dict의 길이는 82669입니다.
# 153000번째 문서 처리 중이며 word_to_freq_dict의 길이는 82964입니다.
# 154000번째 문서 처리 중이며 word_to_freq_dict의 길이는 83194입니다.
# 155000번째 문서 처리 중이며 word_to_freq_dict의 길이는 83458입니다.
# 156000번째 문서 처리 중이며 word_to_freq_dict의 길이는 83716입니다.
# 157000번째 문서 처리 중이며 word_to_freq_dict의 길이는 83987입니다.
# 158000번째 문서 처리 중이며 word_to_freq_dict의 길이는 84238입니다.
# 159000번째 문서 처리 중이며 word_to_freq_dict의 길이는 84534입니다.
# 160000번째 문서 처리 중이며 word_to_freq_dict의 길이는 84809입니다.
# 161000번째 문서 처리 중이며 word_to_freq_dict의 길이는 85047입니다.
# 162000번째 문서 처리 중이며 word_to_freq_dict의 길이는 85280입니다.
# 163000번째 문서 처리 중이며 word_to_freq_dict의 길이는 85519입니다.
# 164000번째 문서 처리 중이며 word_to_freq_dict의 길이는 85731입니다.
# 165000번째 문서 처리 중이며 word_to_freq_dict의 길이는 85951입니다.
# 166000번째 문서 처리 중이며 word_to_freq_dict의 길이는 86193입니다.
# 167000번째 문서 처리 중이며 word_to_freq_dict의 길이는 86442입니다.
# 168000번째 문서 처리 중이며 word_to_freq_dict의 길이는 86735입니다.
# 169000번째 문서 처리 중이며 word_to_freq_dict의 길이는 86982입니다.
# 170000번째 문서 처리 중이며 word_to_freq_dict의 길이는 87203입니다.
# 171000번째 문서 처리 중이며 word_to_freq_dict의 길이는 87463입니다.
# 172000번째 문서 처리 중이며 word_to_freq_dict의 길이는 87677입니다.
# 173000번째 문서 처리 중이며 word_to_freq_dict의 길이는 87914입니다.
# 174000번째 문서 처리 중이며 word_to_freq_dict의 길이는 88171입니다.
# 175000번째 문서 처리 중이며 word_to_freq_dict의 길이는 88385입니다.
# 176000번째 문서 처리 중이며 word_to_freq_dict의 길이는 88654입니다.
# 177000번째 문서 처리 중이며 word_to_freq_dict의 길이는 88894입니다.
# 178000번째 문서 처리 중이며 word_to_freq_dict의 길이는 89126입니다.
# 179000번째 문서 처리 중이며 word_to_freq_dict의 길이는 89398입니다.
# 180000번째 문서 처리 중이며 word_to_freq_dict의 길이는 89621입니다.
# 181000번째 문서 처리 중이며 word_to_freq_dict의 길이는 89863입니다.
# 182000번째 문서 처리 중이며 word_to_freq_dict의 길이는 90077입니다.
# 183000번째 문서 처리 중이며 word_to_freq_dict의 길이는 90304입니다.
# 184000번째 문서 처리 중이며 word_to_freq_dict의 길이는 90515입니다.
# 185000번째 문서 처리 중이며 word_to_freq_dict의 길이는 90742입니다.
# 186000번째 문서 처리 중이며 word_to_freq_dict의 길이는 90958입니다.
# 187000번째 문서 처리 중이며 word_to_freq_dict의 길이는 91156입니다.
# 188000번째 문서 처리 중이며 word_to_freq_dict의 길이는 91419입니다.
# 189000번째 문서 처리 중이며 word_to_freq_dict의 길이는 91625입니다.
# 190000번째 문서 처리 중이며 word_to_freq_dict의 길이는 91887입니다.
# 191000번째 문서 처리 중이며 word_to_freq_dict의 길이는 92105입니다.
# 192000번째 문서 처리 중이며 word_to_freq_dict의 길이는 92363입니다.
# 193000번째 문서 처리 중이며 word_to_freq_dict의 길이는 92572입니다.
# 194000번째 문서 처리 중이며 word_to_freq_dict의 길이는 92787입니다.
# 195000번째 문서 처리 중이며 word_to_freq_dict의 길이는 93017입니다.
# 196000번째 문서 처리 중이며 word_to_freq_dict의 길이는 93226입니다.
# 197000번째 문서 처리 중이며 word_to_freq_dict의 길이는 93433입니다.
# 198000번째 문서 처리 중이며 word_to_freq_dict의 길이는 93668입니다.
# 199000번째 문서 처리 중이며 word_to_freq_dict의 길이는 93913입니다.
# 200000번째 문서 처리 중이며 word_to_freq_dict의 길이는 94148입니다.
# 201000번째 문서 처리 중이며 word_to_freq_dict의 길이는 94352입니다.
# 202000번째 문서 처리 중이며 word_to_freq_dict의 길이는 94555입니다.
# 203000번째 문서 처리 중이며 word_to_freq_dict의 길이는 94793입니다.
# 204000번째 문서 처리 중이며 word_to_freq_dict의 길이는 95043입니다.
# 205000번째 문서 처리 중이며 word_to_freq_dict의 길이는 95274입니다.
# 206000번째 문서 처리 중이며 word_to_freq_dict의 길이는 95497입니다.
# 207000번째 문서 처리 중이며 word_to_freq_dict의 길이는 95722입니다.
# 208000번째 문서 처리 중이며 word_to_freq_dict의 길이는 95987입니다.
# 209000번째 문서 처리 중이며 word_to_freq_dict의 길이는 96226입니다.
# 210000번째 문서 처리 중이며 word_to_freq_dict의 길이는 96489입니다.
# 211000번째 문서 처리 중이며 word_to_freq_dict의 길이는 96715입니다.
# 212000번째 문서 처리 중이며 word_to_freq_dict의 길이는 96936입니다.
# 213000번째 문서 처리 중이며 word_to_freq_dict의 길이는 97146입니다.
# 214000번째 문서 처리 중이며 word_to_freq_dict의 길이는 97359입니다.
# 215000번째 문서 처리 중이며 word_to_freq_dict의 길이는 97580입니다.
# 216000번째 문서 처리 중이며 word_to_freq_dict의 길이는 97789입니다.
# 217000번째 문서 처리 중이며 word_to_freq_dict의 길이는 98002입니다.
# 218000번째 문서 처리 중이며 word_to_freq_dict의 길이는 98217입니다.
# 219000번째 문서 처리 중이며 word_to_freq_dict의 길이는 98478입니다.
# 220000번째 문서 처리 중이며 word_to_freq_dict의 길이는 98665입니다.
# 221000번째 문서 처리 중이며 word_to_freq_dict의 길이는 98868입니다.
# 222000번째 문서 처리 중이며 word_to_freq_dict의 길이는 99084입니다.
# 223000번째 문서 처리 중이며 word_to_freq_dict의 길이는 99281입니다.
# 224000번째 문서 처리 중이며 word_to_freq_dict의 길이는 99525입니다.
# 225000번째 문서 처리 중이며 word_to_freq_dict의 길이는 99760입니다.
# 226000번째 문서 처리 중이며 word_to_freq_dict의 길이는 99960입니다.
# 227000번째 문서 처리 중이며 word_to_freq_dict의 길이는 100181입니다.
# 228000번째 문서 처리 중이며 word_to_freq_dict의 길이는 100396입니다.
# 229000번째 문서 처리 중이며 word_to_freq_dict의 길이는 100591입니다.
# 230000번째 문서 처리 중이며 word_to_freq_dict의 길이는 100788입니다.
# 231000번째 문서 처리 중이며 word_to_freq_dict의 길이는 101045입니다.
# 232000번째 문서 처리 중이며 word_to_freq_dict의 길이는 101233입니다.
# 233000번째 문서 처리 중이며 word_to_freq_dict의 길이는 101407입니다.
# 234000번째 문서 처리 중이며 word_to_freq_dict의 길이는 101647입니다.
# 235000번째 문서 처리 중이며 word_to_freq_dict의 길이는 101843입니다.
# 236000번째 문서 처리 중이며 word_to_freq_dict의 길이는 102070입니다.
# 237000번째 문서 처리 중이며 word_to_freq_dict의 길이는 102299입니다.
# 238000번째 문서 처리 중이며 word_to_freq_dict의 길이는 102488입니다.
# 239000번째 문서 처리 중이며 word_to_freq_dict의 길이는 102733입니다.
# 240000번째 문서 처리 중이며 word_to_freq_dict의 길이는 102940입니다.
# 241000번째 문서 처리 중이며 word_to_freq_dict의 길이는 103095입니다.
# 242000번째 문서 처리 중이며 word_to_freq_dict의 길이는 103309입니다.
# 243000번째 문서 처리 중이며 word_to_freq_dict의 길이는 103523입니다.
# 244000번째 문서 처리 중이며 word_to_freq_dict의 길이는 103712입니다.
# 245000번째 문서 처리 중이며 word_to_freq_dict의 길이는 103949입니다.
# 246000번째 문서 처리 중이며 word_to_freq_dict의 길이는 104149입니다.
# 247000번째 문서 처리 중이며 word_to_freq_dict의 길이는 104338입니다.
# 248000번째 문서 처리 중이며 word_to_freq_dict의 길이는 104508입니다.
# 249000번째 문서 처리 중이며 word_to_freq_dict의 길이는 104680입니다.
# 250000번째 문서 처리 중이며 word_to_freq_dict의 길이는 104901입니다.
# 251000번째 문서 처리 중이며 word_to_freq_dict의 길이는 105074입니다.
# 252000번째 문서 처리 중이며 word_to_freq_dict의 길이는 105249입니다.
# 253000번째 문서 처리 중이며 word_to_freq_dict의 길이는 105450입니다.
# 254000번째 문서 처리 중이며 word_to_freq_dict의 길이는 105658입니다.
# 255000번째 문서 처리 중이며 word_to_freq_dict의 길이는 105839입니다.
# 256000번째 문서 처리 중이며 word_to_freq_dict의 길이는 106019입니다.
# 257000번째 문서 처리 중이며 word_to_freq_dict의 길이는 106219입니다.
# 258000번째 문서 처리 중이며 word_to_freq_dict의 길이는 106449입니다.
# 259000번째 문서 처리 중이며 word_to_freq_dict의 길이는 106674입니다.
# 260000번째 문서 처리 중이며 word_to_freq_dict의 길이는 106885입니다.
# 261000번째 문서 처리 중이며 word_to_freq_dict의 길이는 107069입니다.
# 262000번째 문서 처리 중이며 word_to_freq_dict의 길이는 107251입니다.
# 263000번째 문서 처리 중이며 word_to_freq_dict의 길이는 107455입니다.
# 264000번째 문서 처리 중이며 word_to_freq_dict의 길이는 107623입니다.
# 265000번째 문서 처리 중이며 word_to_freq_dict의 길이는 107816입니다.
# 266000번째 문서 처리 중이며 word_to_freq_dict의 길이는 108024입니다.
# 267000번째 문서 처리 중이며 word_to_freq_dict의 길이는 108233입니다.
# 268000번째 문서 처리 중이며 word_to_freq_dict의 길이는 108451입니다.
# 269000번째 문서 처리 중이며 word_to_freq_dict의 길이는 108646입니다.
# 270000번째 문서 처리 중이며 word_to_freq_dict의 길이는 108844입니다.
# 271000번째 문서 처리 중이며 word_to_freq_dict의 길이는 109006입니다.
# 272000번째 문서 처리 중이며 word_to_freq_dict의 길이는 109221입니다.
# 273000번째 문서 처리 중이며 word_to_freq_dict의 길이는 109418입니다.
# 274000번째 문서 처리 중이며 word_to_freq_dict의 길이는 109604입니다.
# 275000번째 문서 처리 중이며 word_to_freq_dict의 길이는 109840입니다.
# 276000번째 문서 처리 중이며 word_to_freq_dict의 길이는 110052입니다.
# 277000번째 문서 처리 중이며 word_to_freq_dict의 길이는 110240입니다.
# 278000번째 문서 처리 중이며 word_to_freq_dict의 길이는 110439입니다.
# 279000번째 문서 처리 중이며 word_to_freq_dict의 길이는 110593입니다.
# 280000번째 문서 처리 중이며 word_to_freq_dict의 길이는 110789입니다.
# 281000번째 문서 처리 중이며 word_to_freq_dict의 길이는 110976입니다.
# 282000번째 문서 처리 중이며 word_to_freq_dict의 길이는 111168입니다.
# 283000번째 문서 처리 중이며 word_to_freq_dict의 길이는 111329입니다.
# 284000번째 문서 처리 중이며 word_to_freq_dict의 길이는 111512입니다.
# 285000번째 문서 처리 중이며 word_to_freq_dict의 길이는 111685입니다.
# 286000번째 문서 처리 중이며 word_to_freq_dict의 길이는 111861입니다.
# 287000번째 문서 처리 중이며 word_to_freq_dict의 길이는 112037입니다.
# 288000번째 문서 처리 중이며 word_to_freq_dict의 길이는 112206입니다.
# 289000번째 문서 처리 중이며 word_to_freq_dict의 길이는 112417입니다.
# 290000번째 문서 처리 중이며 word_to_freq_dict의 길이는 112614입니다.
# 291000번째 문서 처리 중이며 word_to_freq_dict의 길이는 112802입니다.
# 292000번째 문서 처리 중이며 word_to_freq_dict의 길이는 112978입니다.
# 293000번째 문서 처리 중이며 word_to_freq_dict의 길이는 113171입니다.
# 294000번째 문서 처리 중이며 word_to_freq_dict의 길이는 113380입니다.
# 295000번째 문서 처리 중이며 word_to_freq_dict의 길이는 113534입니다.
# 296000번째 문서 처리 중이며 word_to_freq_dict의 길이는 113748입니다.
# 297000번째 문서 처리 중이며 word_to_freq_dict의 길이는 113940입니다.
# 298000번째 문서 처리 중이며 word_to_freq_dict의 길이는 114118입니다.
# 299000번째 문서 처리 중이며 word_to_freq_dict의 길이는 114305입니다.
# 300000번째 문서 처리 중이며 word_to_freq_dict의 길이는 114474입니다.
# 301000번째 문서 처리 중이며 word_to_freq_dict의 길이는 114675입니다.
# 302000번째 문서 처리 중이며 word_to_freq_dict의 길이는 114893입니다.
# 303000번째 문서 처리 중이며 word_to_freq_dict의 길이는 115063입니다.
# 304000번째 문서 처리 중이며 word_to_freq_dict의 길이는 115244입니다.
# 305000번째 문서 처리 중이며 word_to_freq_dict의 길이는 115447입니다.
# 306000번째 문서 처리 중이며 word_to_freq_dict의 길이는 115633입니다.
# 307000번째 문서 처리 중이며 word_to_freq_dict의 길이는 115824입니다.
# 308000번째 문서 처리 중이며 word_to_freq_dict의 길이는 116008입니다.
# 309000번째 문서 처리 중이며 word_to_freq_dict의 길이는 116165입니다.
# 310000번째 문서 처리 중이며 word_to_freq_dict의 길이는 116353입니다.
# 311000번째 문서 처리 중이며 word_to_freq_dict의 길이는 116544입니다.
# 312000번째 문서 처리 중이며 word_to_freq_dict의 길이는 116750입니다.
# 313000번째 문서 처리 중이며 word_to_freq_dict의 길이는 116933입니다.
# 314000번째 문서 처리 중이며 word_to_freq_dict의 길이는 117102입니다.
# 315000번째 문서 처리 중이며 word_to_freq_dict의 길이는 117291입니다.
# 316000번째 문서 처리 중이며 word_to_freq_dict의 길이는 117486입니다.
# 317000번째 문서 처리 중이며 word_to_freq_dict의 길이는 117683입니다.
# 318000번째 문서 처리 중이며 word_to_freq_dict의 길이는 117873입니다.
# 319000번째 문서 처리 중이며 word_to_freq_dict의 길이는 118060입니다.
# 320000번째 문서 처리 중이며 word_to_freq_dict의 길이는 118255입니다.
# 321000번째 문서 처리 중이며 word_to_freq_dict의 길이는 118411입니다.
# 322000번째 문서 처리 중이며 word_to_freq_dict의 길이는 118613입니다.
# 323000번째 문서 처리 중이며 word_to_freq_dict의 길이는 118803입니다.
# 324000번째 문서 처리 중이며 word_to_freq_dict의 길이는 118951입니다.
# 325000번째 문서 처리 중이며 word_to_freq_dict의 길이는 119097입니다.
# 326000번째 문서 처리 중이며 word_to_freq_dict의 길이는 119247입니다.
# 327000번째 문서 처리 중이며 word_to_freq_dict의 길이는 119390입니다.
# 328000번째 문서 처리 중이며 word_to_freq_dict의 길이는 119570입니다.
# 329000번째 문서 처리 중이며 word_to_freq_dict의 길이는 119756입니다.
# 330000번째 문서 처리 중이며 word_to_freq_dict의 길이는 119932입니다.
# 331000번째 문서 처리 중이며 word_to_freq_dict의 길이는 120133입니다.
# 332000번째 문서 처리 중이며 word_to_freq_dict의 길이는 120311입니다.
# 333000번째 문서 처리 중이며 word_to_freq_dict의 길이는 120466입니다.
# 334000번째 문서 처리 중이며 word_to_freq_dict의 길이는 120646입니다.
# 335000번째 문서 처리 중이며 word_to_freq_dict의 길이는 120805입니다.
# 336000번째 문서 처리 중이며 word_to_freq_dict의 길이는 120974입니다.
# 337000번째 문서 처리 중이며 word_to_freq_dict의 길이는 121148입니다.
# 338000번째 문서 처리 중이며 word_to_freq_dict의 길이는 121327입니다.
# 339000번째 문서 처리 중이며 word_to_freq_dict의 길이는 121494입니다.
# 340000번째 문서 처리 중이며 word_to_freq_dict의 길이는 121656입니다.
# 341000번째 문서 처리 중이며 word_to_freq_dict의 길이는 121830입니다.
# 342000번째 문서 처리 중이며 word_to_freq_dict의 길이는 122017입니다.
# 343000번째 문서 처리 중이며 word_to_freq_dict의 길이는 122195입니다.
# 344000번째 문서 처리 중이며 word_to_freq_dict의 길이는 122357입니다.
# 345000번째 문서 처리 중이며 word_to_freq_dict의 길이는 122536입니다.
# 346000번째 문서 처리 중이며 word_to_freq_dict의 길이는 122715입니다.
# 347000번째 문서 처리 중이며 word_to_freq_dict의 길이는 122870입니다.
# 348000번째 문서 처리 중이며 word_to_freq_dict의 길이는 123028입니다.
# 349000번째 문서 처리 중이며 word_to_freq_dict의 길이는 123213입니다.
# 350000번째 문서 처리 중이며 word_to_freq_dict의 길이는 123365입니다.
# 351000번째 문서 처리 중이며 word_to_freq_dict의 길이는 123548입니다.
# 352000번째 문서 처리 중이며 word_to_freq_dict의 길이는 123738입니다.
# 353000번째 문서 처리 중이며 word_to_freq_dict의 길이는 123926입니다.
# 354000번째 문서 처리 중이며 word_to_freq_dict의 길이는 124153입니다.
# 355000번째 문서 처리 중이며 word_to_freq_dict의 길이는 124310입니다.
# 356000번째 문서 처리 중이며 word_to_freq_dict의 길이는 124480입니다.
# 357000번째 문서 처리 중이며 word_to_freq_dict의 길이는 124640입니다.
# 358000번째 문서 처리 중이며 word_to_freq_dict의 길이는 124783입니다.
# 359000번째 문서 처리 중이며 word_to_freq_dict의 길이는 124950입니다.
# 360000번째 문서 처리 중이며 word_to_freq_dict의 길이는 125113입니다.
# 361000번째 문서 처리 중이며 word_to_freq_dict의 길이는 125278입니다.
# 362000번째 문서 처리 중이며 word_to_freq_dict의 길이는 125451입니다.
# 363000번째 문서 처리 중이며 word_to_freq_dict의 길이는 125604입니다.
# 364000번째 문서 처리 중이며 word_to_freq_dict의 길이는 125784입니다.
# 365000번째 문서 처리 중이며 word_to_freq_dict의 길이는 125947입니다.
# 366000번째 문서 처리 중이며 word_to_freq_dict의 길이는 126119입니다.
# 367000번째 문서 처리 중이며 word_to_freq_dict의 길이는 126307입니다.
# 368000번째 문서 처리 중이며 word_to_freq_dict의 길이는 126450입니다.
# 369000번째 문서 처리 중이며 word_to_freq_dict의 길이는 126597입니다.
# 370000번째 문서 처리 중이며 word_to_freq_dict의 길이는 126752입니다.
# 371000번째 문서 처리 중이며 word_to_freq_dict의 길이는 126951입니다.
# 372000번째 문서 처리 중이며 word_to_freq_dict의 길이는 127102입니다.
# 373000번째 문서 처리 중이며 word_to_freq_dict의 길이는 127269입니다.
# 374000번째 문서 처리 중이며 word_to_freq_dict의 길이는 127453입니다.
# 375000번째 문서 처리 중이며 word_to_freq_dict의 길이는 127622입니다.
# 376000번째 문서 처리 중이며 word_to_freq_dict의 길이는 127799입니다.
# 377000번째 문서 처리 중이며 word_to_freq_dict의 길이는 127953입니다.
# 378000번째 문서 처리 중이며 word_to_freq_dict의 길이는 128120입니다.
# 379000번째 문서 처리 중이며 word_to_freq_dict의 길이는 128271입니다.
# 380000번째 문서 처리 중이며 word_to_freq_dict의 길이는 128466입니다.
# 381000번째 문서 처리 중이며 word_to_freq_dict의 길이는 128631입니다.
# 382000번째 문서 처리 중이며 word_to_freq_dict의 길이는 128809입니다.
# 383000번째 문서 처리 중이며 word_to_freq_dict의 길이는 128973입니다.
# 384000번째 문서 처리 중이며 word_to_freq_dict의 길이는 129133입니다.
# 385000번째 문서 처리 중이며 word_to_freq_dict의 길이는 129287입니다.
# 386000번째 문서 처리 중이며 word_to_freq_dict의 길이는 129460입니다.
# 387000번째 문서 처리 중이며 word_to_freq_dict의 길이는 129632입니다.
# 388000번째 문서 처리 중이며 word_to_freq_dict의 길이는 129792입니다.
# 389000번째 문서 처리 중이며 word_to_freq_dict의 길이는 129962입니다.
# 390000번째 문서 처리 중이며 word_to_freq_dict의 길이는 130112입니다.
# 391000번째 문서 처리 중이며 word_to_freq_dict의 길이는 130289입니다.
# 392000번째 문서 처리 중이며 word_to_freq_dict의 길이는 130472입니다.
# 393000번째 문서 처리 중이며 word_to_freq_dict의 길이는 130640입니다.
# 394000번째 문서 처리 중이며 word_to_freq_dict의 길이는 130794입니다.
# 395000번째 문서 처리 중이며 word_to_freq_dict의 길이는 130965입니다.
# 396000번째 문서 처리 중이며 word_to_freq_dict의 길이는 131119입니다.
# 397000번째 문서 처리 중이며 word_to_freq_dict의 길이는 131294입니다.
# 398000번째 문서 처리 중이며 word_to_freq_dict의 길이는 131448입니다.
# 399000번째 문서 처리 중이며 word_to_freq_dict의 길이는 131603입니다.
# 400000번째 문서 처리 중이며 word_to_freq_dict의 길이는 131761입니다.
# 401000번째 문서 처리 중이며 word_to_freq_dict의 길이는 131921입니다.
# 402000번째 문서 처리 중이며 word_to_freq_dict의 길이는 132059입니다.
# 403000번째 문서 처리 중이며 word_to_freq_dict의 길이는 132220입니다.
# 404000번째 문서 처리 중이며 word_to_freq_dict의 길이는 132375입니다.
# 405000번째 문서 처리 중이며 word_to_freq_dict의 길이는 132538입니다.
# 406000번째 문서 처리 중이며 word_to_freq_dict의 길이는 132688입니다.
# 407000번째 문서 처리 중이며 word_to_freq_dict의 길이는 132835입니다.
# 408000번째 문서 처리 중이며 word_to_freq_dict의 길이는 133007입니다.
# 409000번째 문서 처리 중이며 word_to_freq_dict의 길이는 133154입니다.
# 410000번째 문서 처리 중이며 word_to_freq_dict의 길이는 133297입니다.
# 411000번째 문서 처리 중이며 word_to_freq_dict의 길이는 133467입니다.
# 412000번째 문서 처리 중이며 word_to_freq_dict의 길이는 133653입니다.
# 413000번째 문서 처리 중이며 word_to_freq_dict의 길이는 133813입니다.
# 414000번째 문서 처리 중이며 word_to_freq_dict의 길이는 134016입니다.
# 415000번째 문서 처리 중이며 word_to_freq_dict의 길이는 134193입니다.
# 416000번째 문서 처리 중이며 word_to_freq_dict의 길이는 134374입니다.
# 417000번째 문서 처리 중이며 word_to_freq_dict의 길이는 134529입니다.
# 418000번째 문서 처리 중이며 word_to_freq_dict의 길이는 134697입니다.
# 419000번째 문서 처리 중이며 word_to_freq_dict의 길이는 134844입니다.
# 420000번째 문서 처리 중이며 word_to_freq_dict의 길이는 134982입니다.
# 421000번째 문서 처리 중이며 word_to_freq_dict의 길이는 135141입니다.
# 422000번째 문서 처리 중이며 word_to_freq_dict의 길이는 135283입니다.
# 423000번째 문서 처리 중이며 word_to_freq_dict의 길이는 135454입니다.
# 424000번째 문서 처리 중이며 word_to_freq_dict의 길이는 135623입니다.
# 425000번째 문서 처리 중이며 word_to_freq_dict의 길이는 135762입니다.
# 426000번째 문서 처리 중이며 word_to_freq_dict의 길이는 135936입니다.
# 427000번째 문서 처리 중이며 word_to_freq_dict의 길이는 136079입니다.
# 428000번째 문서 처리 중이며 word_to_freq_dict의 길이는 136224입니다.
# 429000번째 문서 처리 중이며 word_to_freq_dict의 길이는 136373입니다.
# 430000번째 문서 처리 중이며 word_to_freq_dict의 길이는 136528입니다.
# 431000번째 문서 처리 중이며 word_to_freq_dict의 길이는 136680입니다.
# 432000번째 문서 처리 중이며 word_to_freq_dict의 길이는 136808입니다.
# 433000번째 문서 처리 중이며 word_to_freq_dict의 길이는 136985입니다.
# 434000번째 문서 처리 중이며 word_to_freq_dict의 길이는 137129입니다.
# 435000번째 문서 처리 중이며 word_to_freq_dict의 길이는 137271입니다.
# 436000번째 문서 처리 중이며 word_to_freq_dict의 길이는 137415입니다.
# 437000번째 문서 처리 중이며 word_to_freq_dict의 길이는 137596입니다.
# 438000번째 문서 처리 중이며 word_to_freq_dict의 길이는 137748입니다.
# 439000번째 문서 처리 중이며 word_to_freq_dict의 길이는 137902입니다.
# 440000번째 문서 처리 중이며 word_to_freq_dict의 길이는 138066입니다.
# 441000번째 문서 처리 중이며 word_to_freq_dict의 길이는 138219입니다.
# 442000번째 문서 처리 중이며 word_to_freq_dict의 길이는 138376입니다.
# 443000번째 문서 처리 중이며 word_to_freq_dict의 길이는 138554입니다.
# 444000번째 문서 처리 중이며 word_to_freq_dict의 길이는 138708입니다.
# 445000번째 문서 처리 중이며 word_to_freq_dict의 길이는 138830입니다.
# 446000번째 문서 처리 중이며 word_to_freq_dict의 길이는 138978입니다.
# 447000번째 문서 처리 중이며 word_to_freq_dict의 길이는 139108입니다.
# 448000번째 문서 처리 중이며 word_to_freq_dict의 길이는 139228입니다.
# 449000번째 문서 처리 중이며 word_to_freq_dict의 길이는 139352입니다.
# 450000번째 문서 처리 중이며 word_to_freq_dict의 길이는 139519입니다.
# 451000번째 문서 처리 중이며 word_to_freq_dict의 길이는 139662입니다.
# 452000번째 문서 처리 중이며 word_to_freq_dict의 길이는 139845입니다.
# 453000번째 문서 처리 중이며 word_to_freq_dict의 길이는 139999입니다.
# 454000번째 문서 처리 중이며 word_to_freq_dict의 길이는 140157입니다.
# 455000번째 문서 처리 중이며 word_to_freq_dict의 길이는 140291입니다.
# 456000번째 문서 처리 중이며 word_to_freq_dict의 길이는 140416입니다.
# 457000번째 문서 처리 중이며 word_to_freq_dict의 길이는 140590입니다.
# 458000번째 문서 처리 중이며 word_to_freq_dict의 길이는 140763입니다.
# 459000번째 문서 처리 중이며 word_to_freq_dict의 길이는 140932입니다.
# 460000번째 문서 처리 중이며 word_to_freq_dict의 길이는 141082입니다.
# 461000번째 문서 처리 중이며 word_to_freq_dict의 길이는 141258입니다.
# 462000번째 문서 처리 중이며 word_to_freq_dict의 길이는 141425입니다.
# 463000번째 문서 처리 중이며 word_to_freq_dict의 길이는 141560입니다.
# 464000번째 문서 처리 중이며 word_to_freq_dict의 길이는 141710입니다.
# 465000번째 문서 처리 중이며 word_to_freq_dict의 길이는 141896입니다.
# 466000번째 문서 처리 중이며 word_to_freq_dict의 길이는 142025입니다.
# 467000번째 문서 처리 중이며 word_to_freq_dict의 길이는 142180입니다.
# 468000번째 문서 처리 중이며 word_to_freq_dict의 길이는 142333입니다.
# 469000번째 문서 처리 중이며 word_to_freq_dict의 길이는 142617입니다.
# 470000번째 문서 처리 중이며 word_to_freq_dict의 길이는 142752입니다.
# 471000번째 문서 처리 중이며 word_to_freq_dict의 길이는 142903입니다.
# 472000번째 문서 처리 중이며 word_to_freq_dict의 길이는 143048입니다.
# 473000번째 문서 처리 중이며 word_to_freq_dict의 길이는 143197입니다.
# 474000번째 문서 처리 중이며 word_to_freq_dict의 길이는 143321입니다.
# 475000번째 문서 처리 중이며 word_to_freq_dict의 길이는 143469입니다.
# 476000번째 문서 처리 중이며 word_to_freq_dict의 길이는 143610입니다.
# 477000번째 문서 처리 중이며 word_to_freq_dict의 길이는 143748입니다.
# 478000번째 문서 처리 중이며 word_to_freq_dict의 길이는 143908입니다.
# 479000번째 문서 처리 중이며 word_to_freq_dict의 길이는 144065입니다.
# 480000번째 문서 처리 중이며 word_to_freq_dict의 길이는 144230입니다.
# 481000번째 문서 처리 중이며 word_to_freq_dict의 길이는 144368입니다.
# 482000번째 문서 처리 중이며 word_to_freq_dict의 길이는 144504입니다.
# 483000번째 문서 처리 중이며 word_to_freq_dict의 길이는 144664입니다.
# 484000번째 문서 처리 중이며 word_to_freq_dict의 길이는 144814입니다.
# 485000번째 문서 처리 중이며 word_to_freq_dict의 길이는 144969입니다.
# 486000번째 문서 처리 중이며 word_to_freq_dict의 길이는 145145입니다.
# 487000번째 문서 처리 중이며 word_to_freq_dict의 길이는 145295입니다.
# 488000번째 문서 처리 중이며 word_to_freq_dict의 길이는 145469입니다.
# 489000번째 문서 처리 중이며 word_to_freq_dict의 길이는 145596입니다.
# 490000번째 문서 처리 중이며 word_to_freq_dict의 길이는 145762입니다.
# 491000번째 문서 처리 중이며 word_to_freq_dict의 길이는 145883입니다.
# 492000번째 문서 처리 중이며 word_to_freq_dict의 길이는 146037입니다.
# 493000번째 문서 처리 중이며 word_to_freq_dict의 길이는 146215입니다.
# 494000번째 문서 처리 중이며 word_to_freq_dict의 길이는 146360입니다.
# 495000번째 문서 처리 중이며 word_to_freq_dict의 길이는 146526입니다.
# 496000번째 문서 처리 중이며 word_to_freq_dict의 길이는 146690입니다.
# 497000번째 문서 처리 중이며 word_to_freq_dict의 길이는 146825입니다.
# 498000번째 문서 처리 중이며 word_to_freq_dict의 길이는 146937입니다.
# 499000번째 문서 처리 중이며 word_to_freq_dict의 길이는 147126입니다.
# 500000번째 문서 처리 중이며 word_to_freq_dict의 길이는 147226입니다.
# 501000번째 문서 처리 중이며 word_to_freq_dict의 길이는 147358입니다.
# 502000번째 문서 처리 중이며 word_to_freq_dict의 길이는 147530입니다.
# 503000번째 문서 처리 중이며 word_to_freq_dict의 길이는 147648입니다.
# 504000번째 문서 처리 중이며 word_to_freq_dict의 길이는 147858입니다.
# 505000번째 문서 처리 중이며 word_to_freq_dict의 길이는 147993입니다.
# 506000번째 문서 처리 중이며 word_to_freq_dict의 길이는 148151입니다.
# 507000번째 문서 처리 중이며 word_to_freq_dict의 길이는 148291입니다.
# 508000번째 문서 처리 중이며 word_to_freq_dict의 길이는 148414입니다.
# 509000번째 문서 처리 중이며 word_to_freq_dict의 길이는 148545입니다.
# 510000번째 문서 처리 중이며 word_to_freq_dict의 길이는 148731입니다.
# 511000번째 문서 처리 중이며 word_to_freq_dict의 길이는 148877입니다.
# 512000번째 문서 처리 중이며 word_to_freq_dict의 길이는 149023입니다.
# 513000번째 문서 처리 중이며 word_to_freq_dict의 길이는 149147입니다.
# 514000번째 문서 처리 중이며 word_to_freq_dict의 길이는 149277입니다.
# 515000번째 문서 처리 중이며 word_to_freq_dict의 길이는 149389입니다.
# 516000번째 문서 처리 중이며 word_to_freq_dict의 길이는 149548입니다.
# 517000번째 문서 처리 중이며 word_to_freq_dict의 길이는 149693입니다.
# 518000번째 문서 처리 중이며 word_to_freq_dict의 길이는 149853입니다.
# 519000번째 문서 처리 중이며 word_to_freq_dict의 길이는 149992입니다.
# 520000번째 문서 처리 중이며 word_to_freq_dict의 길이는 150129입니다.
# 521000번째 문서 처리 중이며 word_to_freq_dict의 길이는 150267입니다.
# 522000번째 문서 처리 중이며 word_to_freq_dict의 길이는 150438입니다.
# 523000번째 문서 처리 중이며 word_to_freq_dict의 길이는 150563입니다.
# 524000번째 문서 처리 중이며 word_to_freq_dict의 길이는 150739입니다.
# 525000번째 문서 처리 중이며 word_to_freq_dict의 길이는 150867입니다.
# 526000번째 문서 처리 중이며 word_to_freq_dict의 길이는 151013입니다.
# 527000번째 문서 처리 중이며 word_to_freq_dict의 길이는 151151입니다.
# 528000번째 문서 처리 중이며 word_to_freq_dict의 길이는 151275입니다.
# 529000번째 문서 처리 중이며 word_to_freq_dict의 길이는 151411입니다.
# 530000번째 문서 처리 중이며 word_to_freq_dict의 길이는 151563입니다.
# 531000번째 문서 처리 중이며 word_to_freq_dict의 길이는 151715입니다.
# 532000번째 문서 처리 중이며 word_to_freq_dict의 길이는 151861입니다.
# 533000번째 문서 처리 중이며 word_to_freq_dict의 길이는 151997입니다.
# 534000번째 문서 처리 중이며 word_to_freq_dict의 길이는 152124입니다.
# 535000번째 문서 처리 중이며 word_to_freq_dict의 길이는 152246입니다.
# 536000번째 문서 처리 중이며 word_to_freq_dict의 길이는 152385입니다.
# 537000번째 문서 처리 중이며 word_to_freq_dict의 길이는 152509입니다.
# 538000번째 문서 처리 중이며 word_to_freq_dict의 길이는 152636입니다.
# 539000번째 문서 처리 중이며 word_to_freq_dict의 길이는 152771입니다.
# 540000번째 문서 처리 중이며 word_to_freq_dict의 길이는 152894입니다.
# 541000번째 문서 처리 중이며 word_to_freq_dict의 길이는 153052입니다.
# 542000번째 문서 처리 중이며 word_to_freq_dict의 길이는 153231입니다.
# 543000번째 문서 처리 중이며 word_to_freq_dict의 길이는 153364입니다.
# 544000번째 문서 처리 중이며 word_to_freq_dict의 길이는 153500입니다.
# 545000번째 문서 처리 중이며 word_to_freq_dict의 길이는 153623입니다.
# 546000번째 문서 처리 중이며 word_to_freq_dict의 길이는 153752입니다.
# 547000번째 문서 처리 중이며 word_to_freq_dict의 길이는 153896입니다.
# 548000번째 문서 처리 중이며 word_to_freq_dict의 길이는 154034입니다.
# 549000번째 문서 처리 중이며 word_to_freq_dict의 길이는 154156입니다.
# 550000번째 문서 처리 중이며 word_to_freq_dict의 길이는 154303입니다.
# 551000번째 문서 처리 중이며 word_to_freq_dict의 길이는 154410입니다.
# 552000번째 문서 처리 중이며 word_to_freq_dict의 길이는 154543입니다.
# 553000번째 문서 처리 중이며 word_to_freq_dict의 길이는 154707입니다.
# 554000번째 문서 처리 중이며 word_to_freq_dict의 길이는 154834입니다.
# 555000번째 문서 처리 중이며 word_to_freq_dict의 길이는 154986입니다.
# 556000번째 문서 처리 중이며 word_to_freq_dict의 길이는 155136입니다.
# 557000번째 문서 처리 중이며 word_to_freq_dict의 길이는 155268입니다.
# 558000번째 문서 처리 중이며 word_to_freq_dict의 길이는 155409입니다.
# 559000번째 문서 처리 중이며 word_to_freq_dict의 길이는 155584입니다.
# 560000번째 문서 처리 중이며 word_to_freq_dict의 길이는 155734입니다.
# 561000번째 문서 처리 중이며 word_to_freq_dict의 길이는 155863입니다.
# 562000번째 문서 처리 중이며 word_to_freq_dict의 길이는 156008입니다.
# 563000번째 문서 처리 중이며 word_to_freq_dict의 길이는 156138입니다.
# 564000번째 문서 처리 중이며 word_to_freq_dict의 길이는 156288입니다.
# 565000번째 문서 처리 중이며 word_to_freq_dict의 길이는 156446입니다.
# 566000번째 문서 처리 중이며 word_to_freq_dict의 길이는 156590입니다.
# 567000번째 문서 처리 중이며 word_to_freq_dict의 길이는 156689입니다.
# 568000번째 문서 처리 중이며 word_to_freq_dict의 길이는 156836입니다.
# 569000번째 문서 처리 중이며 word_to_freq_dict의 길이는 156957입니다.
# 570000번째 문서 처리 중이며 word_to_freq_dict의 길이는 157080입니다.
# 571000번째 문서 처리 중이며 word_to_freq_dict의 길이는 157218입니다.
# 572000번째 문서 처리 중이며 word_to_freq_dict의 길이는 157326입니다.
# 573000번째 문서 처리 중이며 word_to_freq_dict의 길이는 157468입니다.
# 574000번째 문서 처리 중이며 word_to_freq_dict의 길이는 157599입니다.
# 575000번째 문서 처리 중이며 word_to_freq_dict의 길이는 157703입니다.
# 576000번째 문서 처리 중이며 word_to_freq_dict의 길이는 157828입니다.
# 577000번째 문서 처리 중이며 word_to_freq_dict의 길이는 157966입니다.
# 578000번째 문서 처리 중이며 word_to_freq_dict의 길이는 158094입니다.
# 579000번째 문서 처리 중이며 word_to_freq_dict의 길이는 158242입니다.
# 580000번째 문서 처리 중이며 word_to_freq_dict의 길이는 158370입니다.
# 581000번째 문서 처리 중이며 word_to_freq_dict의 길이는 158487입니다.
# 582000번째 문서 처리 중이며 word_to_freq_dict의 길이는 158612입니다.
# 583000번째 문서 처리 중이며 word_to_freq_dict의 길이는 158721입니다.
# 584000번째 문서 처리 중이며 word_to_freq_dict의 길이는 158874입니다.
# 585000번째 문서 처리 중이며 word_to_freq_dict의 길이는 159001입니다.
# 586000번째 문서 처리 중이며 word_to_freq_dict의 길이는 159134입니다.
# 587000번째 문서 처리 중이며 word_to_freq_dict의 길이는 159267입니다.
# 588000번째 문서 처리 중이며 word_to_freq_dict의 길이는 159386입니다.
# 589000번째 문서 처리 중이며 word_to_freq_dict의 길이는 159514입니다.
# 590000번째 문서 처리 중이며 word_to_freq_dict의 길이는 159639입니다.
# 591000번째 문서 처리 중이며 word_to_freq_dict의 길이는 159778입니다.
# 592000번째 문서 처리 중이며 word_to_freq_dict의 길이는 159945입니다.
# 593000번째 문서 처리 중이며 word_to_freq_dict의 길이는 160081입니다.
# 594000번째 문서 처리 중이며 word_to_freq_dict의 길이는 160199입니다.
# 595000번째 문서 처리 중이며 word_to_freq_dict의 길이는 160336입니다.
# 596000번째 문서 처리 중이며 word_to_freq_dict의 길이는 160466입니다.
# 597000번째 문서 처리 중이며 word_to_freq_dict의 길이는 160597입니다.
# 598000번째 문서 처리 중이며 word_to_freq_dict의 길이는 160738입니다.
# 599000번째 문서 처리 중이며 word_to_freq_dict의 길이는 160867입니다.
# 600000번째 문서 처리 중이며 word_to_freq_dict의 길이는 161010입니다.
# 601000번째 문서 처리 중이며 word_to_freq_dict의 길이는 161121입니다.
# 602000번째 문서 처리 중이며 word_to_freq_dict의 길이는 161263입니다.
# 603000번째 문서 처리 중이며 word_to_freq_dict의 길이는 161414입니다.
# 604000번째 문서 처리 중이며 word_to_freq_dict의 길이는 161573입니다.
# 605000번째 문서 처리 중이며 word_to_freq_dict의 길이는 161683입니다.
# 606000번째 문서 처리 중이며 word_to_freq_dict의 길이는 161828입니다.
# 607000번째 문서 처리 중이며 word_to_freq_dict의 길이는 161969입니다.
# 608000번째 문서 처리 중이며 word_to_freq_dict의 길이는 162117입니다.
# 609000번째 문서 처리 중이며 word_to_freq_dict의 길이는 162238입니다.
# 610000번째 문서 처리 중이며 word_to_freq_dict의 길이는 162378입니다.
# 611000번째 문서 처리 중이며 word_to_freq_dict의 길이는 162501입니다.
# 612000번째 문서 처리 중이며 word_to_freq_dict의 길이는 162628입니다.
# 613000번째 문서 처리 중이며 word_to_freq_dict의 길이는 162764입니다.
# 614000번째 문서 처리 중이며 word_to_freq_dict의 길이는 162886입니다.
# 615000번째 문서 처리 중이며 word_to_freq_dict의 길이는 163014입니다.
# 616000번째 문서 처리 중이며 word_to_freq_dict의 길이는 163111입니다.
# 617000번째 문서 처리 중이며 word_to_freq_dict의 길이는 163244입니다.
# 618000번째 문서 처리 중이며 word_to_freq_dict의 길이는 163394입니다.
# 619000번째 문서 처리 중이며 word_to_freq_dict의 길이는 163499입니다.
# 620000번째 문서 처리 중이며 word_to_freq_dict의 길이는 163644입니다.
# 621000번째 문서 처리 중이며 word_to_freq_dict의 길이는 163759입니다.
# 622000번째 문서 처리 중이며 word_to_freq_dict의 길이는 163885입니다.
# 623000번째 문서 처리 중이며 word_to_freq_dict의 길이는 164019입니다.
# 624000번째 문서 처리 중이며 word_to_freq_dict의 길이는 164132입니다.
# 625000번째 문서 처리 중이며 word_to_freq_dict의 길이는 164260입니다.
# 626000번째 문서 처리 중이며 word_to_freq_dict의 길이는 164384입니다.
# 627000번째 문서 처리 중이며 word_to_freq_dict의 길이는 164545입니다.
# 628000번째 문서 처리 중이며 word_to_freq_dict의 길이는 164657입니다.
# 629000번째 문서 처리 중이며 word_to_freq_dict의 길이는 164777입니다.
# 630000번째 문서 처리 중이며 word_to_freq_dict의 길이는 164898입니다.
# 631000번째 문서 처리 중이며 word_to_freq_dict의 길이는 165021입니다.
# 632000번째 문서 처리 중이며 word_to_freq_dict의 길이는 165168입니다.
# 633000번째 문서 처리 중이며 word_to_freq_dict의 길이는 165315입니다.
# 634000번째 문서 처리 중이며 word_to_freq_dict의 길이는 165467입니다.
# 635000번째 문서 처리 중이며 word_to_freq_dict의 길이는 165617입니다.
# 636000번째 문서 처리 중이며 word_to_freq_dict의 길이는 165760입니다.
# 637000번째 문서 처리 중이며 word_to_freq_dict의 길이는 165904입니다.
# 638000번째 문서 처리 중이며 word_to_freq_dict의 길이는 166028입니다.
# 639000번째 문서 처리 중이며 word_to_freq_dict의 길이는 166151입니다.
# 640000번째 문서 처리 중이며 word_to_freq_dict의 길이는 166285입니다.
# 641000번째 문서 처리 중이며 word_to_freq_dict의 길이는 166425입니다.
# 642000번째 문서 처리 중이며 word_to_freq_dict의 길이는 166574입니다.
# 643000번째 문서 처리 중이며 word_to_freq_dict의 길이는 166717입니다.
# 644000번째 문서 처리 중이며 word_to_freq_dict의 길이는 166841입니다.
# 645000번째 문서 처리 중이며 word_to_freq_dict의 길이는 166969입니다.
# 646000번째 문서 처리 중이며 word_to_freq_dict의 길이는 167117입니다.
# 647000번째 문서 처리 중이며 word_to_freq_dict의 길이는 167248입니다.
# 648000번째 문서 처리 중이며 word_to_freq_dict의 길이는 167360입니다.
# 649000번째 문서 처리 중이며 word_to_freq_dict의 길이는 167470입니다.
# 650000번째 문서 처리 중이며 word_to_freq_dict의 길이는 167587입니다.
# 651000번째 문서 처리 중이며 word_to_freq_dict의 길이는 167722입니다.
# 652000번째 문서 처리 중이며 word_to_freq_dict의 길이는 167842입니다.
# 653000번째 문서 처리 중이며 word_to_freq_dict의 길이는 167975입니다.
# 654000번째 문서 처리 중이며 word_to_freq_dict의 길이는 168093입니다.
# 655000번째 문서 처리 중이며 word_to_freq_dict의 길이는 168218입니다.
# 656000번째 문서 처리 중이며 word_to_freq_dict의 길이는 168348입니다.
# 657000번째 문서 처리 중이며 word_to_freq_dict의 길이는 168443입니다.
# 658000번째 문서 처리 중이며 word_to_freq_dict의 길이는 168565입니다.
# 659000번째 문서 처리 중이며 word_to_freq_dict의 길이는 168678입니다.
# 660000번째 문서 처리 중이며 word_to_freq_dict의 길이는 168808입니다.
# 661000번째 문서 처리 중이며 word_to_freq_dict의 길이는 168915입니다.
# 662000번째 문서 처리 중이며 word_to_freq_dict의 길이는 169050입니다.
# 663000번째 문서 처리 중이며 word_to_freq_dict의 길이는 169154입니다.
# 664000번째 문서 처리 중이며 word_to_freq_dict의 길이는 169291입니다.
# 665000번째 문서 처리 중이며 word_to_freq_dict의 길이는 169394입니다.
# 666000번째 문서 처리 중이며 word_to_freq_dict의 길이는 169524입니다.
# 667000번째 문서 처리 중이며 word_to_freq_dict의 길이는 169636입니다.
# 668000번째 문서 처리 중이며 word_to_freq_dict의 길이는 169771입니다.
# 669000번째 문서 처리 중이며 word_to_freq_dict의 길이는 169875입니다.

# %%
idx_to_word_dict = {idx:val for val,idx in word_to_idx_dict.items()}

# %%
import pickle

# %%
def save_obj(obj, name):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(obj,name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
save_obj(word_to_idx_dict,'word_to_idx_dict')
save_obj(word_to_freq_dict,'word_to_freq_dict')

# %%
def word_to_idx(doc,min_freq=5) : 
    """
    doc : train or validation or test datasets which are composed with list within list
    """

    min_freq_ls = [[word for word in sent if word_to_freq_dict[word] > min_freq] for sent in doc]
    idx_dict = \
    [[word_to_idx_dict[word] if word in word_to_idx_dict.keys() else 0 for word in sent]\
     for sent in min_freq_ls] #if there is no tokens which match with  test datasets vocab then, that token is changed into UNK token
    return idx_dict

# %%
train_X = [word_to_idx(batch[0]) for batch in x_train]
test_X = [word_to_idx(batch[0]) for batch in x_test]

# %% [markdown]
# - max_sent_len : 한 문서가 가지는 최대 문장 갯수이자, 최소 문장 갯수입니다.(패딩 적용)
# - max_seq_len : 한 문장이 가지는 최대 단어 갯수이자, 최소 단어 갯수입니다. (패딩 적용)

# %%
## Padding the number of sentence
train_X = [doc + [[1]]*(max_sent_len - len(doc)) if len(doc) <= max_sent_len else doc[:max_sent_len]\
           for doc in train_X]
test_X = [doc + [[1]]*(max_sent_len - len(doc)) if len(doc) <= max_sent_len else doc[:max_sent_len]\
           for doc in test_X]

## Padding the number of word
train_X = [[sent + [1] * (max_seq_len - len(sent)) for sent in doc] for doc in train_X]
test_X = [[sent + [1] * (max_seq_len - len(sent)) for sent in doc] for doc in test_X]

# %% [markdown]
# ## Make Datasets with iterators

# %%
print("한 문장 안에 있는 단어의 길이 : ",set([len(sent) for doc in train_X for sent in doc]))
print("한 문서 안에 있는 문장의 길이 : ",set([len(doc) for doc in train_X]))
# Out:
# 한 문장 안에 있는 단어의 길이 :  {25}
# 한 문서 안에 있는 문장의 길이 :  {12}

# %%
# 뒤에 나오는 DataLoader는 Cuda Tensor를 지원하지 않습니다.
train_X = torch.LongTensor(train_X)
train_y = torch.LongTensor(y_train.tolist())
test_X = torch.LongTensor(test_X)
test_y = torch.LongTensor(y_test.tolist())

# %%
train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# (torch.Size([670000, 12, 25]),
#  torch.Size([670000]),
#  torch.Size([330000, 12, 25]),
#  torch.Size([330000]))

# %%
torch.save(train_X,'train_X.pt')
torch.save(train_y,'train_y.pt')

torch.save(test_X,'test_X.pt')
torch.save(test_y,'test_y.pt')

# %% [markdown]
# ## 만약 커널을 끄고 다시 시작하실 경우, 여기서부터 진행하면 됩니다!!

# %%
def save_obj(obj, name):
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %%
word_to_idx_dict = load_obj('word_to_idx_dict')
word_to_freq_dict = load_obj('word_to_freq_dict')

# %%
train_X = torch.load('train_X.pt')
train_y = torch.load('train_y.pt')
test_X = torch.load('test_X.pt')
test_y = torch.load('test_y.pt')

# %%
class Dataset(data.Dataset):
    def __init__(self, X, y):
        'Initialization'
        self.y = y
        self.X = X

    def __len__(self):
        'Denotes the total number of samples'
        return len(self.X)

    def __getitem__(self, index):
        # Load data and get label
        'Generates one sample of data'
        # Select sample
        X = self.X[index]
        y = self.y[index]

        return X, y

# %%
# Parameters
params = {'batch_size': 100,
          'shuffle': True,
          'num_workers': 10}

# Generators
training_set = Dataset(train_X,train_y)
train_iter = data.DataLoader(training_set, **params)

testing_set = Dataset(test_X,test_y)
test_iter = data.DataLoader(testing_set, **params)

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

for local_batch, local_labels in train_iter:
    local_batch, local_labels = local_batch.to(device), local_labels.to(device)
    break

# %%
local_batch.size(),local_labels.size()
#[batch_size, sent_len, word_len]
# 25개의 단어를 가지고 12개의 문장을 가진 64개의 문서가 있는 것입니다.
# Out:
# (torch.Size([100, 12, 25]), torch.Size([100]))

# %% [markdown]
# # Pre-trained GloVe Embedding Vectors

# %%
import numpy as np

# %%
# Extract word embeddings from the Glove
embeddings_index = dict()
f = open('glove.twitter.27B.200d.txt')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

# %%
matrix_len = len(word_to_idx_dict)
weights_matrix = np.zeros((matrix_len, 200))
words_found = 0

for i, word in enumerate(word_to_idx_dict.keys()):
    try: 
        weights_matrix[i] = embeddings_index[word]
        words_found += 1
    except KeyError:
        weights_matrix[i] = np.random.normal(scale=0.6, size=(200, ))
        
print("전체 단어의 길이 {} 개에서 GloVe 벡터로 초기화된 단어의 갯수는 {} 개입니다.".format(len(word_to_idx_dict),words_found))
# Out:
# 전체 단어의 길이 170007 개에서 GloVe 벡터로 초기화된 단어의 갯수는 83087 개입니다.

# %%
weights_matrix.shape
# Out:
# (170007, 200)

# %% [markdown]
# # Modeling

# %%
class WordAttention(nn.Module) : 
    
    def __init__(self,batch_size,hidden_size) : 
        
        super(WordAttention,self).__init__() 
        self.batch_size = batch_size
        self.linear = nn.Linear(hidden_size*2,hidden_size*2).to(device)
        self.word_proj_params = nn.Parameter(torch.Tensor(hidden_size*2,1)).to(device)
        self.initialize_weight()
        
    def initialize_weight(self) : 
        torch.nn.init.xavier_uniform_(self.linear.weight)
        torch.nn.init.xavier_uniform_(self.word_proj_params)
        
    def forward(self,outputs) : 
        
        outputs = outputs.permute(1,0,2) #[batch_size, sent_len, hidden_dim*2]

        u = torch.tanh(self.linear(outputs)) #[batch_size, sent_len, hidden_dim*2]  
        word_proj_params = self.word_proj_params.expand(self.batch_size,-1,-1) #[batch_size,hidden_dim*2,1]
    
        atten = torch.bmm(u,word_proj_params) #[batch_size,sent_len,1]
        a = torch.softmax(atten,dim=1) #[batch_size,sent_len,1]
        s = torch.sum(torch.mul(a,outputs),dim=1) #[batch_size,hidden_dim*2]
        
        return s,a

# %%
def create_emb_layer(weights_matrix):
    num_embeddings, embedding_dim = weights_matrix.shape
    emb_layer = nn.Embedding(num_embeddings, embedding_dim,padding_idx = 1) # <pad>
    emb_layer.weight = nn.Parameter(torch.tensor(weights_matrix,dtype=torch.float32))
    
    return emb_layer
    
class WordRNN(nn.Module) : 
    
    def __init__(self,batch_size,vocab_size,embed_size,hidden_size,num_layer,max_sent_len,weights_matrix) : 
        
        super(WordRNN,self).__init__()
        self.batch_size = batch_size
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        self.gru_hidden_size = hidden_size
        self.num_layer = num_layer
        self.max_sent_len = max_sent_len
#         self.embeddings = nn.Embedding(vocab_size,embed_size,padding_idx = 1).to(device)
        self.embeddings = create_emb_layer(weights_matrix).to(device)
        # GloVe 로 Initialize만 시키고, Training이 가능하게 해줍니다.
        self.gru = nn.GRU(embed_size,hidden_size,num_layer,bidirectional=True).to(device)
        
        self.word_atten = WordAttention(batch_size,hidden_size).to(device)
        self.initialize_weight()
        
    def initialize_weight(self) : 
        for layer_p in gru._all_weights:
            for p in layer_p:
                if 'weight' in p:
                    nn.init.xavier_normal_(gru.__getattr__(p),)

    def forward(self,input_,hidden) : 
        
        sent_vec_ls = []; word_attention_ls = []
        
        for i in range(self.max_sent_len) : 
            x = input_[:,i,:]  # x : [batch_size, T :(word length per sentence)]
            embeds = self.embeddings(x).permute(1,0,2) # [T, batch_size, embed_dim] 

            outputs, hidden = self.gru(embeds,hidden)
            
            sent_vec,word_attention = self.word_atten(outputs)
        
            sent_vec_ls.append(sent_vec.unsqueeze(1))
            word_attention_ls.append(word_attention.permute(0,2,1))
        
        sent_vec = torch.cat(sent_vec_ls,dim=1)
        word_attention = torch.cat(word_attention_ls,dim=1)
                
        return sent_vec,word_attention,hidden
    # [batch_size,sent_len,hidden_size]
    # [batch_size,sent_len,word_len]
    # [num_layer*bidirectional(2), batch_size, hidden_size]

# %%
batch_size = 100
vocab_size = len(word_to_idx_dict)
embed_size = 200
hidden_size = 50
num_layer = 1
max_sent_len = 12

word_model = WordRNN(batch_size,vocab_size,embed_size,hidden_size,num_layer,max_sent_len,weights_matrix)
hidden = \
        Variable(torch.randn(num_layer*2, batch_size, hidden_size, device=device))

# %%
sent_vec,word_attention,hidden = word_model(local_batch,hidden)

# %%
class SentAttention(nn.Module) : 
    
    def __init__(self,batch_size,hidden_size) : 
        
        super(SentAttention,self).__init__() 
        self.batch_size = batch_size
        self.linear = nn.Linear(hidden_size*2,hidden_size*2).to(device)
        self.sent_proj_params = nn.Parameter(torch.Tensor(hidden_size*2,1)).to(device)
        self.initialize_weight()
        
    def initialize_weight(self) : 
        torch.nn.init.xavier_uniform_(self.linear.weight)
        torch.nn.init.xavier_uniform_(self.sent_proj_params)
        
    def forward(self,outputs) : 
        
        outputs = outputs.permute(1,0,2) #[batch_size, doc_len, hidden_dim*2]
        u = torch.tanh(self.linear(outputs)) #[batch_size, doc_len, hidden_dim*2]
        sent_proj_params = self.sent_proj_params.expand(self.batch_size,-1,-1) #[batch_size,hidden_dim*2,1]
        atten = torch.bmm(u,sent_proj_params) #[batch_size,doc_len,1]
        a = torch.softmax(atten,dim=1) #[batch_size,doc_len,1]
        v = torch.sum(a * outputs,dim=1) #[batch_size,hidden_dim*2]
        return v,a

# %%
class SentRNN(nn.Module) : 
    
    def __init__(self,batch_size,vocab_size,embed_size,hidden_size,num_layer) : 
        
        super(SentRNN,self).__init__()
        self.batch_size = batch_size
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        self.gru_hidden_size = hidden_size
        self.num_layer = num_layer
        
        self.gru = nn.GRU(hidden_size*2,hidden_size,num_layer,bidirectional=True).to(device)
        
        self.sent_atten = SentAttention(batch_size,hidden_size)
        self.initialize_weight()
        
    def initialize_weight(self) : 
        for layer_p in gru._all_weights:
            for p in layer_p:
                if 'weight' in p:
                    nn.init.xavier_normal_(gru.__getattr__(p),)

    def forward(self,x,hidden) : 
        
        x = x.permute(1,0,2) #x : [doc_len,batch_size, hidden*2]

        outputs, hidden = self.gru(x,hidden)
    
        doc_vec,sent_attention = self.sent_atten(outputs)
        
        return doc_vec,sent_attention,hidden
    
    #[batch_size,hidden_dim*2]
    #[batch_size,doc_len,1]
    #[num_layer*2,batch_size,hidden_dim]

# %%
sent_model = SentRNN(batch_size,vocab_size,embed_size,hidden_size,num_layer)

# %%
doc_vec,sent_attention,hidden = sent_model(sent_vec,hidden)

# %%
class HAN(nn.Module) : 
    
    def __init__(self,batch_size,vocab_size,embed_size,hidden_size,num_layer,max_sent_len,num_class,weights_matrix) : 
        
        super(HAN,self).__init__()
        self.batch_size = batch_size
        self.vocab_size = vocab_size
        self.embed_size = embed_size
        self.hidden_size = hidden_size
        self.num_layers = num_layer
        self.max_sent_len = max_sent_len
        self.num_class = num_class
        self.device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    
        self.word_encoder =\
        WordRNN(batch_size,vocab_size,embed_size,hidden_size,num_layer,max_sent_len,weights_matrix).to(self.device)
        
        self.sent_encoder =\
        SentRNN(batch_size,vocab_size,embed_size,hidden_size,num_layer).to(self.device)
        
        self.proj_layer = nn.Linear(hidden_size*2,num_class).to(self.device)
        self.initialize_weight()
        
    def initialize_weight(self) : 
        torch.nn.init.xavier_uniform_(self.proj_layer.weight)
        
    def init_hidden(self,batch_size):
        hidden = \
        Variable(torch.zeros(self.num_layers*2, batch_size, self.hidden_size, device=self.device))
            
        return hidden
    
    def forward(self,input_) : 
        
        (batch_size,sent_len,doc_len) = input_.size()
        
        word_encoder_hidden = self.init_hidden(batch_size)
        sent_vec,word_attention,hidden = self.word_encoder(input_,word_encoder_hidden)
        sent_vec = nn.LayerNorm(self.hidden_size*2).to(device)(sent_vec)
        
        sent_encoder_hidden = self.init_hidden(batch_size)
        doc_vec,sent_attention,hidden = self.sent_encoder(sent_vec,sent_encoder_hidden)
        doc_vec = nn.LayerNorm(self.hidden_size*2).to(device)(doc_vec)
        
        logit = self.proj_layer(doc_vec)
        log_softmax = torch.log_softmax(logit,dim=1)
        
        return log_softmax, word_attention, sent_attention

# %%
params = {'batch_size' : 100,
'vocab_size' : len(word_to_idx_dict),
'embed_size' : 200,
'hidden_size' : 50,
'num_layer' : 1,
'max_sent_len' : 12,       
'num_class' : 5,
'weights_matrix' : weights_matrix,
}

model = HAN(**params).to(device)
model
# Out:
# HAN(
#   (word_encoder): WordRNN(
#     (embeddings): Embedding(170007, 200, padding_idx=1)
#     (gru): GRU(200, 50, bidirectional=True)
#     (word_atten): WordAttention(
#       (linear): Linear(in_features=100, out_features=100, bias=True)
#     )
#   )
#   (sent_encoder): SentRNN(
#     (gru): GRU(100, 50, bidirectional=True)
#     (sent_atten): SentAttention(
#       (linear): Linear(in_features=100, out_features=100, bias=True)
#     )
#   )
#   (proj_layer): Linear(in_features=100, out_features=5, bias=True)
# )

# %%
log_softmax, word_attention, sent_attention = model(local_batch)

# %% [markdown]
# # Trainig and Testing

# %%
def adjust_learning_rate(optimizer, epoch, init_lr=0.1, decay = 0.1 ,per_epoch=10):
    """Decay learning rate by a factor of 0.1 every lr_decay_epoch epochs."""
    for param_group in optimizer.param_groups:
        param_group['lr'] *= 1/(1 + decay)

    return optimizer , float(param_group['lr'])

# %%
def train(model,train_loader , test_loader , epochs = 10, lr = 0.01, batch_size = 100) :
    
    optimizer = torch.optim.Adam(model.parameters(),lr)
    criterion = nn.NLLLoss().to(device)

    for epoch in range(1,epochs+1) :
        optimizer , lr_int = \
        adjust_learning_rate(optimizer, epoch, init_lr=lr, decay = 0.1 ,per_epoch=10)
        model.train()        
        n_correct = 0
        batch_count = 0
        for local_batch, local_labels in train_loader:
            
            batch_count += 1 
            if batch_count % 1000 == 0 : 
                print("{}번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.".format(batch_count))
                
            local_batch,local_labels = local_batch.to(device),local_labels.to(device)
        
            train_softmax, word_attention, sent_attention = model(local_batch)
            train_predict = train_softmax.argmax(dim=1)

            n_correct += (train_predict == local_labels).sum().item()            
            loss = criterion(train_softmax,local_labels)
            
            if loss.item() == 'nan' : 
                return local_batch,local_labels,train_softmax,word_attention,sent_attention
            
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            
        acc = n_correct / (len(train_loader) * batch_size)  
        with open('log.txt', 'a') as f:
            f.write('Train epoch : %s,  loss : %s,  accuracy :%.3f, learning rate :%.3f\n\n'%(epoch, loss.item(), acc,lr_int))
            
        print('Train epoch : %s,  loss : %s,  accuracy :%.3f, learning rate :%.3f'%(epoch, loss.item(), acc,lr_int))
        print('=================================================================================================')
        
        if (epoch) % 2 == 0:
            model.eval()
            n_correct = 0  # accuracy 계산을 위해 맞은 갯수 카운트
            val_loss = 0

            for local_batch, local_labels in test_loader:
                local_batch,local_labels = local_batch.to(device),local_labels.to(device)
                
                test_softmax, word_attention, sent_attention = model(local_batch)
                test_predict = test_softmax.argmax(dim = 1)

                val_loss = criterion(test_softmax, local_labels)
                
                n_correct += (test_predict == local_labels).sum().item() #맞은 갯수                

            val_acc = n_correct / (len(test_loader) * batch_size)
            with open('log.txt','a') as f : 
                f.write('Val Epoch : %s, Val Loss : %.03f , Val Accuracy : %.03f\n\n'%(epoch, val_loss, val_acc))
                
            print('*************************************************************************************************')
            print('*************************************************************************************************')
            print('Val Epoch : %s, Val Loss : %.03f , Val Accuracy : %.03f'%(epoch, val_loss, val_acc))
            print('*************************************************************************************************')
            print('*************************************************************************************************')

# %%
local_batch,local_labels,train_softmax,word_attention,sent_attention = \
train(model, train_iter, test_iter, epochs=30)
# Out:
# 1000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 2000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 3000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 4000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 5000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 6000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# Train epoch : 1,  loss : 0.7867679595947266,  accuracy :0.658, learning rate :0.009
# =================================================================================================
# 1000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 2000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 3000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 4000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 5000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 6000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# Train epoch : 2,  loss : 0.6004376411437988,  accuracy :0.665, learning rate :0.008
# =================================================================================================
# *************************************************************************************************
# *************************************************************************************************
# Val Epoch : 2, Val Loss : 0.686 , Val Accuracy : 0.659
# *************************************************************************************************
# *************************************************************************************************
# 1000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 2000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 3000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 4000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 5000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 6000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# Train epoch : 3,  loss : 0.8486897945404053,  accuracy :0.668, learning rate :0.008
# =================================================================================================
# 1000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 2000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 3000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 4000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 5000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 6000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# Train epoch : 4,  loss : 0.6839591264724731,  accuracy :0.671, learning rate :0.007
# =================================================================================================
# *************************************************************************************************
# *************************************************************************************************
# Val Epoch : 4, Val Loss : 0.830 , Val Accuracy : 0.663
# *************************************************************************************************
# *************************************************************************************************
# 1000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 2000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 3000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 4000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 5000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 6000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# Train epoch : 5,  loss : 0.723807156085968,  accuracy :0.673, learning rate :0.006
# =================================================================================================
# 1000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 2000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 3000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 4000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 5000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 6000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# Train epoch : 6,  loss : 0.7063800692558289,  accuracy :0.675, learning rate :0.006
# =================================================================================================
# *************************************************************************************************
# *************************************************************************************************
# Val Epoch : 6, Val Loss : 0.832 , Val Accuracy : 0.658
# *************************************************************************************************
# *************************************************************************************************
# 2000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 3000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 4000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 5000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 6000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# Train epoch : 7,  loss : 0.7294747829437256,  accuracy :0.677, learning rate :0.005
# =================================================================================================
# 1000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 2000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 3000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 4000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 5000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 6000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# Train epoch : 8,  loss : 0.7387301921844482,  accuracy :0.678, learning rate :0.005
# =================================================================================================
# *************************************************************************************************
# *************************************************************************************************
# Val Epoch : 8, Val Loss : 0.978 , Val Accuracy : 0.665
# *************************************************************************************************
# *************************************************************************************************
# 1000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 2000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 3000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 4000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 5000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 6000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# Train epoch : 9,  loss : 0.8197939991950989,  accuracy :0.680, learning rate :0.004
# =================================================================================================
# 1000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 2000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 3000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 4000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 5000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 6000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# Train epoch : 10,  loss : 0.8035174608230591,  accuracy :0.681, learning rate :0.004
# =================================================================================================
# *************************************************************************************************
# *************************************************************************************************
# Val Epoch : 10, Val Loss : 0.685 , Val Accuracy : 0.666
# *************************************************************************************************
# *************************************************************************************************
# 1000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 2000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 3000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 4000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 5000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 6000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# Train epoch : 11,  loss : 0.8112872838973999,  accuracy :0.682, learning rate :0.004
# =================================================================================================
# 1000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 2000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 3000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 4000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 5000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 6000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# Train epoch : 12,  loss : 0.7385613918304443,  accuracy :0.683, learning rate :0.003
# =================================================================================================
# *************************************************************************************************
# *************************************************************************************************
# Val Epoch : 12, Val Loss : 0.806 , Val Accuracy : 0.666
# *************************************************************************************************
# *************************************************************************************************
# 1000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 2000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 3000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 4000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 5000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 6000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# Train epoch : 13,  loss : 0.8115079402923584,  accuracy :0.686, learning rate :0.003
# =================================================================================================
# 1000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 2000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 3000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 4000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 5000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 6000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# Train epoch : 14,  loss : 0.766478419303894,  accuracy :0.687, learning rate :0.003
# =================================================================================================
# *************************************************************************************************
# *************************************************************************************************
# Val Epoch : 14, Val Loss : 0.747 , Val Accuracy : 0.670
# *************************************************************************************************
# *************************************************************************************************
# 1000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# 2000번째 배치가 돌고 있습니다. 한 에포크는 6700입니다.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-0d7380220347> in <module>
#       1 local_batch,local_labels,train_softmax,word_attention,sent_attention = \
# ----> 2 train(model, train_iter, test_iter, epochs=30)
#
# <ipython-input-68-863d687ac4e0> in train(model, train_loader, test_loader, epochs, lr, batch_size)
#      18             local_batch,local_labels = local_batch.to(device),local_labels.to(device)
#      19
# ---> 20             train_softmax, word_attention, sent_attention = model(local_batch)
#      21             train_predict = train_softmax.argmax(dim=1)
#      22
#
# ~/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-61-1e5be1e931c8> in forward(self, input_)
#      36
#      37         word_encoder_hidden = self.init_hidden(batch_size)
# ---> 38         sent_vec,word_attention,hidden = self.word_encoder(input_,word_encoder_hidden)
#      39         sent_vec = nn.LayerNorm(self.hidden_size*2).to(device)(sent_vec)
#      40
#
# ~/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-41-707eb770f29b> in forward(self, input_, hidden)
#      39             embeds = self.embeddings(x).permute(1,0,2) # [T, batch_size, embed_dim]
#      40
# ---> 41             outputs, hidden = self.gru(embeds,hidden)
#      42
#      43             sent_vec,word_attention = self.word_atten(outputs)
#
# ~/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     177         if batch_sizes is None:
#     178             result = _impl(input, hx, self._flat_weights, self.bias, self.num_layers,
# --> 179                            self.dropout, self.training, self.bidirectional, self.batch_first)
#     180         else:
#     181             result = _impl(input, batch_sizes, hx, self._flat_weights, self.bias,
#
# KeyboardInterrupt:

# %%
torch.save(model,'HAN.pt')
# Out:
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type HAN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type WordRNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type WordAttention. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type SentRNN. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# /home/fin/anaconda3/envs/engine_3.6/lib/python3.6/site-packages/torch/serialization.py:251: UserWarning: Couldn't retrieve source code for container of type SentAttention. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %% [markdown]
# ` params = {'batch_size' : 100,
# 'vocab_size' : len(word_to_idx_dict),
#  'embed_size' : 128,
#  'hidden_size' : 100,
#  'num_layer' : 1,
#  'max_sent_len' : 12,
#  'num_class' : 5}`
#
# **Highest Validation Accuracy at Epoch 15 without pretrained embedding and Layer Normalization BUT there was no weight initialization such as xavier so, word attention wasn't changed and NaN values are appeared sometimes: 0.59**
# ____________________
# `params = {'batch_size' : 100,
#  'vocab_size' : len(word_to_idx_dict),
#  'embed_size' : 200,
#  'hidden_size' : 50,
#  'num_layer' : 1,
#  'max_sent_len' : 12,
#  'num_class' : 5
#  }`
#
#  **Highest Validation Accuracy at Epoch 15 : 0.40**
#  ____________________
#  ` params = {'batch_size' : 100,
# 'vocab_size' : len(word_to_idx_dict),
#  'embed_size' : 128,
#  'hidden_size' : 100,
#  'num_layer' : 1,
#  'max_sent_len' : 12,
#  'num_class' : 5}`
#
# **Highest Validation Accuracy at Epoch 15 without pretrained embedding and Layer Normalization with xavier weight normalization: 0.67**

# %% [markdown]
# # Implication
# - 최종 test accuracy는 약 60퍼센트이다.

# %%
batch = next(iter(test_iter))
X = batch[0].cuda(); y = batch[1].cuda()

# %%
log_softmax, word_attention, sent_attention = model(X.cuda())

# %%
correct_ratio = (log_softmax.argmax(dim=1) == y).sum().item() / batch_size

print("한 배치 사이즈에 대한 Accuracy는 {} % 입니다.".format(correct_ratio*100))
# Out:
# 한 배치 사이즈에 대한 Accuracy는 70.0 % 입니다.

# %%
doc_ls = [[idx_to_word_dict[word.item()] for word in sent if word != 1]for sent in X[0]]

# %%
pd.DataFrame.from_dict(\
    dict(zip([','.join(sent).replace(",",' ') for sent in doc_ls],\
         [i.item() for i in sent_attention[0]])),orient='index',columns=['sent_attn_score'])\
            .sort_values('sent_attn_score',ascending=False)
# Out:
#                                                     sent_attn_score
# this place was a disappointment and way overpri...         0.125161
# unfortunately   it was horrible ! ! !                      0.123758
# the pork came with beans and they were way too ...         0.121092
# the pork tasted like it was a day old and it was           0.098670
# we also ordered the caesar salad and it was dou...         0.098664
# had to ask for a replacement with dressing on t...         0.098221
# my wife got the kailua pig as it was also recom...         0.071795
# the service was the best part of the meal                  0.071777
# so   we were told the calamari is very fresh an...         0.069570
# it did taste very good and we were excited for ...         0.069570
#                                                            0.025836

# %% [markdown]
# # Coloring to word and sentence under Attention score
#
# - **Text colors** :
#     - grey : relative influencial word in positive sentence (first quatile)
#     - red : relative influencial word in negative sentence (first quatile)
#     - green : relative non-influencial word in sentence
#
# - **Text highlights** :
#     - on_grey : relative influencial word in positive doc (first quatile)
#     - on_red : relative influencial word in negative doc (first quatile)
#     - on_green : relative non-influencial word in doc

# %%
def coloring(model,X,y,index,sent_attention,word_attention,first_threshold=80,second_treshold=60) : 
    
    sent_ls = np.array([idx_to_word_dict[word.item()] for sent in X[index] for word in sent])
    sent_attention_ls = np.array([i[0].item() for i in sent_attention[index] for _ in range(25)])
    word_attention_ls = np.array([j.item() for i in word_attention[index] for j in i])

    first_sent_attn_threshold = np.percentile(sent_attention_ls,first_threshold)
    first_word_attn_threshold = np.percentile(word_attention_ls,first_threshold)

    second_sent_attn_threshold = np.percentile(sent_attention_ls,second_treshold)

    colored_doc = []

    for word,sent_attn,word_attn in zip(sent_ls,sent_attention_ls,word_attention_ls) : 
        color_ls = ''
        if word == '<pad>' : continue
        if sent_attn > first_sent_attn_threshold : 
            color_ls = 'green'
            if word_attn > first_word_attn_threshold : 
                colored_doc.append(colored(word,color_ls,attrs=['underline']))
            else : colored_doc.append(colored(word,color_ls))
        elif sent_attn > second_sent_attn_threshold : 
            color_ls = 'yellow'
            if word_attn > first_word_attn_threshold : 
                colored_doc.append(colored(word,color_ls,attrs=['underline']))
            else : colored_doc.append(colored(word,color_ls))
        else : 
            color_ls = 'grey'
            if word_attn > first_word_attn_threshold : 
                colored_doc.append(colored(word,color_ls,attrs=['underline']))
            else : colored_doc.append(colored(word,color_ls))
                
    for i in colored_doc : 
        print(i,end=' ')
    
    print("\n")
    display(Markdown('### The true label is {} and our model predicts the label {}.\
    If the model misclassifies the label, then the annotation might be also wrong.'\
         .format(y[index].item(),(model(X)[0].argmax(1) == y)[index].item())))

# %%
coloring(model,X,y,0,sent_attention,word_attention,first_threshold=90)
# Out:
# so , we were told the calamari is very fresh and has it did taste very good and we were excited for our dinner my wife got the kailua pig as it was also recommended unfortunately , it was horrible ! ! ! the pork tasted like it was a day old and it was the pork came with beans and they were way too salty we also ordered the caesar salad and it was doused with dressing had to ask for a replacement with dressing on the side this place was a disappointment and way overpriced ! the service was the best part of the meal
# ### The true label is 0 and our model predicts the label 0.    If the model misclassifies the label, then the annotation might be also wrong.
